# %%
import numpy as np
import argparse
import os
import imp
import re
import pickle
import datetime
import random
import math
import copy

from sklearn.model_selection import KFold, StratifiedKFold
import torch
from torch import nn
import torch.nn.utils.rnn as rnn_utils
from torch.utils import data
from torch.autograd import Variable
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader,TensorDataset,random_split,SubsetRandomSampler, ConcatDataset, Subset

from utils import metrics

# %% [markdown]
# ### Base Transformer model

# %%
input_dim = 25
pad_token = np.zeros(input_dim)
def pad_sents(sents, pad_token):

    sents_padded = []

    max_length = max([len(_) for _ in sents])
    for i in sents:
        padded = list(i) + [pad_token]*(max_length-len(i))
        sents_padded.append(np.array(padded))

    return np.array(sents_padded)

# %%
def get_bce_loss(y_pred, y_true):
    loss = torch.nn.BCELoss()
    return loss(y_pred[:,-1], y_true)

# %%
def predict_last_visit_bce_loss(y_pred, x_lab_length, y_true):
    # print(y_pred.shape, y_true.shape)
    batch_size = len(y_true)
    loss = torch.nn.BCELoss()
    indices = torch.arange(batch_size, dtype=torch.int64)
    # print(type(indices), indices)
    losses = 0
    for i in indices:
        # print(type(i), i)
        # print('y_pred', y_pred[i][0][0], y_pred.shape)
        # print(x_lab_length)
        # print('x_lab_len', x_lab_length[i])
        # print(y_pred[i][[x_lab_length[i]-1])
        # print(y_true[i.long()])
        losses += (loss(y_pred[i][x_lab_length[i].long()-1], y_true[i]))

    # print(loss(y_pred[:,-1], y_true))
    # return loss(y_pred[:,-1], y_true)
    # print(losses/batch_size)
    return losses/batch_size

# %%
def predict_last_visit_mse_loss(y_pred, x_lab_length, y_true):
    # print('!!!')
    mini_batch_size = y_pred.shape[0]
    loss = torch.nn.MSELoss()
    indices = torch.arange(mini_batch_size, dtype=torch.int64)
    losses = 0
    # print('bs:', mini_batch_size)
    for i in indices:
        losses += (loss(y_pred[i][x_lab_length[i].long()-1], y_true[i][x_lab_length[i].long()-1]))
    return losses/mini_batch_size

# %%
class Dataset(data.Dataset):
    def __init__(self, x_lab, x_lab_length, x_demo, y_outcome, y_los):
        self.x_lab = x_lab
        self.x_lab_length = x_lab_length
        self.x_demo = x_demo
        self.y_outcome = y_outcome
        self.y_los = y_los

    def __getitem__(self, index): # 返回的是tensor
        return self.x_lab[index], self.x_lab_length[index], self.x_demo[index], self.y_outcome[index], self.y_los[index]

    def __len__(self):
        return len(self.y_outcome)

# %%
data_path = './dataset/tongji/processed_data/'
file_name = './ckpt/gru.pth'

batch_size = 64
num_epochs = 30
device = torch.device("cuda:0" if torch.cuda.is_available() == True else 'cpu')
#device = torch.device('cpu')
print("available device: {}".format(device))


x_lab = pickle.load(open('./dataset/tongji/processed_data/train_x_labtest.pkl', 'rb'))
x_lab = np.array(x_lab, dtype=object)
x_lab = [torch.Tensor(_) for _ in x_lab]

x_demo = pickle.load(open('./dataset/tongji/processed_data/train_x_demographic.pkl', 'rb'))
x_demo = np.array(x_demo)

y_outcome = pickle.load(open('./dataset/tongji/processed_data/train_y_outcome.pkl', 'rb'))
y_outcome = np.array(y_outcome)

y_los = pickle.load(open('./dataset/tongji/processed_data/train_y_LOS.pkl', 'rb'))
y_los = np.array(y_los, dtype=object)
y_los = [torch.Tensor(_) for _ in y_los]

# print(len(x_lab[0][0]))
# x_lab = pad_sents(x_lab, pad_token)
# print(x_lab.shape)
x_lab_length = [len(_) for _ in x_lab]
x_lab_length = np.array(x_lab_length)
x_lab = torch.nn.utils.rnn.pad_sequence((x_lab), batch_first=True)
y_los = torch.nn.utils.rnn.pad_sequence(y_los, batch_first=True)
# y_los = (y_los-35)/10
# print(x_lab.shape)
# x_lab = torch.nn.utils.rnn.pack_sequence((x_lab), enforce_sorted=False)
# print(x_lab_length)
# len(x_lab[7])
# Out:
# available device: cpu

# %%
train_dataset = Dataset(x_lab, x_lab_length, x_demo, y_outcome, y_los)
# train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

print(x_lab.shape)
print(x_demo.shape)
# print(len(y[0]))
# print(len(y[1]))
# print(y)

# print(train_dataset.x_lab)
# Out:
# torch.Size([361, 13, 25])
# (361, 2)

# %%
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED) # numpy
random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED) # cpu
torch.cuda.manual_seed(RANDOM_SEED) # gpu
torch.backends.cudnn.deterministic=True # cudnn
np.set_printoptions(threshold=np.inf, precision=2, suppress=True)


def train_epoch(model, device, dataloader, loss_fn, optimizer):
    train_loss = []
    model.train()
    for step, data in enumerate(dataloader):   
        batch_x_lab, batch_x_lab_length, batch_x_demo, batch_y_outcome, batch_y_los = data
        batch_x_lab, batch_x_lab_length, batch_x_demo, batch_y_outcome, batch_y_los = batch_x_lab.float(),batch_x_lab_length.float() , batch_x_demo.float().to(device), batch_y_outcome.float(), batch_y_los.float()
        batch_y = batch_y_los
        batch_y = batch_y.unsqueeze(-1)
        optimizer.zero_grad()
        output = model(batch_x_lab, batch_x_lab_length, batch_x_demo)
        # print(output.shape, batch_x_lab_length.shape, batch_y.shape)
        loss = loss_fn(output, batch_x_lab_length, batch_y)
        train_loss.append(loss.item())
        loss.backward()
        optimizer.step()
    return np.array(train_loss).mean()

def val_epoch(model, device, dataloader, loss_fn):
    val_loss = []
    y_pred = []
    y_true = []
    evaluation_scores = {}
    model.eval()
    with torch.no_grad():
        for step, data in enumerate(dataloader):   
            batch_x_lab, batch_x_lab_length, batch_x_demo, batch_y_outcome, batch_y_los = data
            batch_x_lab, batch_x_lab_length, batch_x_demo, batch_y_outcome, batch_y_los = batch_x_lab.float(),batch_x_lab_length.float() , batch_x_demo.float().to(device), batch_y_outcome.float(), batch_y_los.float()
            batch_y = batch_y_los
            batch_y = batch_y.unsqueeze(-1)
            output = model(batch_x_lab, batch_x_lab_length, batch_x_demo)
            loss = loss_fn(output, batch_x_lab_length, batch_y)
            val_loss.append(loss.item())
            y_pred += [output[i][batch_x_lab_length[i].long()-1][0] for i in range(len(batch_y))]
            # y_pred += [output[i][batch_x_lab_length[i].long()-1][0] for i in range(len(batch_y))]
            # y_true += list(batch_y.cpu().numpy().flatten())
            y_true += [batch_y[i][batch_x_lab_length[i].long()-1][0] for i in range(len(batch_y))]
    # y_pred = np.array(y_pred)
    # y_pred = np.stack([1 - y_pred, y_pred], axis=1)
    try:
        evaluation_scores = metrics.print_metrics_regression(y_true, y_pred)
    except:
        print('error')
    return np.array(val_loss).mean(), evaluation_scores

def test_epoch(model, device, dataloader, loss_fn):
    test_loss = []
    y_pred = []
    y_true = []
    evaluation_scores = {}
    model.eval()
    with torch.no_grad():
        for step, data in enumerate(dataloader):   
            batch_x_lab, batch_x_lab_length, batch_x_demo, batch_y_outcome, batch_y_los = data
            batch_x_lab, batch_x_lab_length, batch_x_demo, batch_y_outcome, batch_y_los = batch_x_lab.float(),batch_x_lab_length.float() , batch_x_demo.float().to(device), batch_y_outcome.float(), batch_y_los.float()
            batch_y = batch_y_los
            batch_y = batch_y.unsqueeze(-1)
            output = model(batch_x_lab, batch_x_lab_length, batch_x_demo)
            loss = loss_fn(output, batch_x_lab_length, batch_y)
            test_loss.append(loss.item())
            
            # y_pred += list(output.cpu().numpy().flatten())
            y_pred += [output[i][batch_x_lab_length[i].long()-1].cpu().numpy().flatten() for i in range(len(batch_y))]
            # y_true += list(batch_y.cpu().numpy().flatten())
            y_true += [batch_y[i][batch_x_lab_length[i].long()-1][0] for i in range(len(batch_y))]
    # y_pred = np.array(y_pred)
    # y_pred = np.stack([1 - y_pred, y_pred], axis=1)
    try:
        evaluation_scores = metrics.print_metrics_regression(y_true, y_pred)
    except:
        print('error')
    return np.array(test_loss).mean(), evaluation_scores

# train_epoch(model, device, train_loader, get_bce_loss, optimizer)

# %%
class Transformer(nn.Module):
    def __init__(self, input_lab_dim, input_demo_dim, hidden_dim, output_dim, act_layer=nn.GELU, drop=0.):
        super(Transformer, self).__init__()

        # hyperparameters
        self.input_lab_dim = input_lab_dim
        self.input_demo_dim = input_demo_dim
        self.hidden_dim = hidden_dim
        self.output_dim = output_dim
        
        self.demo_proj = nn.Linear(input_demo_dim, hidden_dim)
        self.lab_proj = nn.Linear(input_lab_dim, hidden_dim)

        self.encoder_layer = nn.TransformerEncoderLayer(d_model=hidden_dim, nhead=4, dim_feedforward=512, activation='gelu')
        self.transformer_encoder = nn.TransformerEncoder(self.encoder_layer, num_layers=1)

        self.gru = nn.GRU(input_size = hidden_dim, hidden_size = hidden_dim, num_layers = 1, batch_first = True)
        
        self.act = act_layer()
        self.fc = nn.Linear(2*hidden_dim, output_dim)
        self.drop = nn.Dropout(drop)

        self.sigmoid = nn.Sigmoid()

    def forward(self, x_lab, x_lab_length, x_demo):
        batch_size, max_length, input_dim = x_lab.shape

        x_lab = self.lab_proj(x_lab)
        x_lab = self.act(x_lab)
        # print('1', x_lab.shape)
        x_lab, h_n = self.gru(x_lab)
        # x_lab = self.transformer_encoder(x_lab)
        # print('2', x_lab.shape)

        x_demo = self.demo_proj(x_demo)
        x_demo = self.act(x_demo) # (batch_size, hidden_dim)

        x_demo = torch.reshape(x_demo.repeat(1, max_length), (batch_size, max_length, self.hidden_dim))

        # print(x_lab.shape, x_demo.shape)
        x = torch.cat((x_lab, x_demo), 2) # (batch_size, 2*hidden_dim)

        # print(x.shape)
        x = self.drop(x)
        x = self.fc(x)
        x = self.drop(x)
        
        x = self.sigmoid(x)
        return x

# %%
model = Transformer(input_lab_dim=25, input_demo_dim=2, hidden_dim=32, output_dim=1, act_layer=nn.GELU, drop=0.).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
criterion = predict_last_visit_mse_loss
train_loader = DataLoader(train_dataset, batch_size=batch_size)
# train_loss = train_epoch(model, device, train_loader, criterion, optimizer)
train_loss, evaluation_scores = val_epoch(model, device, train_loader, criterion)
# Out:
# Custom bins confusion matrix:
# [[194   0   0   0]
#  [  8   0   0   0]
#  [153   0   0   0]
#  [  6   0   0   0]]
# Mean absolute deviation (MAD) = 31.737485885620117
# Mean squared error (MSE) = 2076.579345703125
# Mean absolute percentage error (MAPE) = 142.18716621398926
# Cohen kappa score = 0.0

# %%
# print(evaluation_scores['mad'])
# print(evaluation_scores['mse'])
# print(evaluation_scores['mape'])

# %% [markdown]
# ### Train, Validate and Test

# %%
all_history={}
test_performance={'test_loss': [],'test_mad':[], 'test_mse':[], 'test_mape':[]}
dataset = train_dataset
num_folds = 5
kfold_test = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=RANDOM_SEED)

for fold_test, (train_and_val_idx, test_idx) in enumerate(kfold_test.split(np.arange(len(dataset)), dataset.y_outcome)):
    print('====== Test Fold {} ======'.format(fold_test + 1))
    kfold_val = StratifiedKFold(n_splits=num_folds-1, shuffle=True, random_state=RANDOM_SEED)
    sub_dataset = Dataset(dataset.x_lab[train_and_val_idx], dataset.x_lab_length[train_and_val_idx], dataset.x_demo[train_and_val_idx], dataset.y_outcome[train_and_val_idx], dataset.y_los[train_and_val_idx])
    all_history['test_fold_{}'.format(fold_test+1)] = {}
    for fold_val, (train_idx, val_idx) in enumerate(kfold_val.split(np.arange(len(sub_dataset)), sub_dataset.y_outcome)):
        print('Val Fold {}'.format(fold_val + 1))
        train_sampler = SubsetRandomSampler(train_idx)
        val_sampler = SubsetRandomSampler(val_idx)
        train_loader = DataLoader(dataset, batch_size=batch_size, sampler=train_sampler)
        val_loader = DataLoader(dataset, batch_size=batch_size, sampler=val_sampler)
        model = Transformer(input_lab_dim=25, input_demo_dim=2, hidden_dim=32, output_dim=1, act_layer=nn.GELU, drop=0.).to(device)
        optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
        criterion = predict_last_visit_mse_loss # get_bce_loss
        history = {'train_loss': [], 'val_loss': [],'val_mad':[], 'val_mse':[], 'val_mape':[]}
        # history = {}
        for epoch in range(num_epochs):
            train_loss=train_epoch(model, device, train_loader, criterion, optimizer)
            val_loss, val_evaluation_scores=val_epoch(model, device, val_loader, criterion)
            # save performance history on validation set
            print("Epoch:{}/{} AVG Training Loss:{:.3f} AVG Val Loss:{:.3f}".format(epoch + 1, num_epochs, train_loss, val_loss))
            history['train_loss'].append(train_loss)
            history['val_loss'].append(val_loss)
            history['val_mad'].append(val_evaluation_scores['mad'])
            history['val_mse'].append(val_evaluation_scores['mse'])
            history['val_mape'].append(val_evaluation_scores['mape'])
        all_history['test_fold_{}'.format(fold_test+1)]['fold{}'.format(fold_val+1)] = history
    
    # at the same epoch, calculate average auroc of each fold, set the best one as the best model
    best_epoch = 0
    best_performance = 0.0
    for step in range(num_epochs):
        mape_list = []
        for fold in range(num_folds-1):
            mape_list.append(all_history['test_fold_{}'.format(fold_test+1)]['fold{}'.format(fold+1)]['val_mape'][step])
        performance = np.array(mape_list).mean()
        if performance > best_performance:
            best_performance = performance
            best_epoch = step + 1
        print('Epoch:{}/{} AVG MAPE:{:.3f}'.format(step+1, num_epochs, performance))

    print(f"Best epoch: {best_epoch} Best performance: {best_performance}")
    print('Begin to evaluate the best model on test set')
    # train model again with train_and_val set (num_epochs = best_epoch), then test on test dataset 
    train_sampler = SubsetRandomSampler(train_and_val_idx)
    test_sampler = SubsetRandomSampler(test_idx)
    train_loader = DataLoader(dataset, batch_size=batch_size, sampler=train_sampler)
    test_loader = DataLoader(dataset, batch_size=batch_size, sampler=test_sampler)
    model = Transformer(input_lab_dim=25, input_demo_dim=2, hidden_dim=32, output_dim=1, act_layer=nn.GELU, drop=0.).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
    criterion = predict_last_visit_mse_loss # get_bce_loss
    for epoch in range(best_epoch):
        train_loss=train_epoch(model, device, train_loader, criterion, optimizer)
        print("Epoch:{}/{} AVG Training Loss:{:.3f}".format(epoch + 1, num_epochs, train_loss))
    test_loss, test_evaluation_scores = test_epoch(model, device, test_loader, criterion)
    test_performance['test_loss'].append(test_loss)
    test_performance['test_mad'].append(test_evaluation_scores['mad'])
    test_performance['test_mse'].append(test_evaluation_scores['mse'])
    test_performance['test_mape'].append(test_evaluation_scores['mape'])
    print(f"Performance on test set {fold_test+1}: MAD = {test_evaluation_scores['mape']}, MSE = {test_evaluation_scores['mse']}, MAPE = {test_evaluation_scores['mape']}")
# Out:
# ====== Test Fold 1 ======
# Val Fold 1
# Custom bins confusion matrix:
# [[49  0  0  0]
#  [ 2  0  0  0]
#  [20  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 22.11336326599121
# Mean squared error (MSE) = 1433.1431884765625
# Mean absolute percentage error (MAPE) = 148.52372407913208
# Cohen kappa score = 0.0
# Epoch:1/30 AVG Training Loss:1572.763 AVG Val Loss:1583.534
# Custom bins confusion matrix:
# [[49  0  0  0]
#  [ 2  0  0  0]
#  [20  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 22.10232925415039
# Mean squared error (MSE) = 1432.1876220703125
# Mean absolute percentage error (MAPE) = 150.91769695281982
# Cohen kappa score = 0.0
# Epoch:2/30 AVG Training Loss:1532.718 AVG Val Loss:1347.440
# Custom bins confusion matrix:
# [[49  0  0  0]
#  [ 2  0  0  0]
#  [20  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 22.091535568237305
# Mean squared error (MSE) = 1431.23486328125
# Mean absolute percentage error (MAPE) = 153.3866047859192
# Cohen kappa score = 0.0
# Epoch:3/30 AVG Training Loss:1534.662 AVG Val Loss:1559.885
# Custom bins confusion matrix:
# [[49  0  0  0]
#  [ 2  0  0  0]
#  [20  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 22.08061408996582
# Mean squared error (MSE) = 1430.25048828125
# Mean absolute percentage error (MAPE) = 155.94806671142578
# Cohen kappa score = 0.0
# Epoch:4/30 AVG Training Loss:1416.937 AVG Val Loss:1589.179
# Custom bins confusion matrix:
# [[49  0  0  0]
#  [ 2  0  0  0]
#  [20  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 22.06946563720703
# Mean squared error (MSE) = 1429.2513427734375
# Mean absolute percentage error (MAPE) = 158.59415531158447
# Cohen kappa score = 0.0
# Epoch:5/30 AVG Training Loss:1600.505 AVG Val Loss:1579.756
# Custom bins confusion matrix:
# [[49  0  0  0]
#  [ 2  0  0  0]
#  [20  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 22.05780029296875
# Mean squared error (MSE) = 1428.2091064453125
# Mean absolute percentage error (MAPE) = 161.37537956237793
# Cohen kappa score = 0.0
# Epoch:6/30 AVG Training Loss:1620.218 AVG Val Loss:1841.261
# Custom bins confusion matrix:
# [[49  0  0  0]
#  [ 2  0  0  0]
#  [20  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 22.04553985595703
# Mean squared error (MSE) = 1427.1220703125
# Mean absolute percentage error (MAPE) = 164.32160139083862
# Cohen kappa score = 0.0
# Epoch:7/30 AVG Training Loss:1706.351 AVG Val Loss:803.467
# Custom bins confusion matrix:
# [[49  0  0  0]
#  [ 2  0  0  0]
#  [20  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 22.03244972229004
# Mean squared error (MSE) = 1425.9749755859375
# Mean absolute percentage error (MAPE) = 167.5029754638672
# Cohen kappa score = 0.0
# Epoch:8/30 AVG Training Loss:1485.564 AVG Val Loss:2172.402
# Custom bins confusion matrix:
# [[49  0  0  0]
#  [ 2  0  0  0]
#  [20  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 22.018714904785156
# Mean squared error (MSE) = 1424.7999267578125
# Mean absolute percentage error (MAPE) = 170.89765071868896
# Cohen kappa score = 0.0
# Epoch:9/30 AVG Training Loss:1474.582 AVG Val Loss:1317.253
# Custom bins confusion matrix:
# [[49  0  0  0]
#  [ 2  0  0  0]
#  [20  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 22.00446319580078
# Mean squared error (MSE) = 1423.620361328125
# Mean absolute percentage error (MAPE) = 174.46662187576294
# Cohen kappa score = 0.0
# Epoch:10/30 AVG Training Loss:1515.585 AVG Val Loss:1333.160
# Custom bins confusion matrix:
# [[49  0  0  0]
#  [ 2  0  0  0]
#  [20  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 21.989158630371094
# Mean squared error (MSE) = 1422.422607421875
# Mean absolute percentage error (MAPE) = 178.45399379730225
# Cohen kappa score = 0.0
# Epoch:11/30 AVG Training Loss:1405.875 AVG Val Loss:1321.194
# Custom bins confusion matrix:
# [[49  0  0  0]
#  [ 2  0  0  0]
#  [20  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 21.97332000732422
# Mean squared error (MSE) = 1421.27099609375
# Mean absolute percentage error (MAPE) = 182.7962040901184
# Cohen kappa score = 0.0
# Epoch:12/30 AVG Training Loss:1501.614 AVG Val Loss:1313.977
# Custom bins confusion matrix:
# [[49  0  0  0]
#  [ 2  0  0  0]
#  [20  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 21.956863403320312
# Mean squared error (MSE) = 1420.1763916015625
# Mean absolute percentage error (MAPE) = 187.58206367492676
# Cohen kappa score = 0.0
# Epoch:13/30 AVG Training Loss:1496.108 AVG Val Loss:799.422
# Custom bins confusion matrix:
# [[49  0  0  0]
#  [ 2  0  0  0]
#  [20  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 21.94069480895996
# Mean squared error (MSE) = 1419.17626953125
# Mean absolute percentage error (MAPE) = 192.59817600250244
# Cohen kappa score = 0.0
# Epoch:14/30 AVG Training Loss:1536.577 AVG Val Loss:1586.577
# Custom bins confusion matrix:
# [[49  0  0  0]
#  [ 2  0  0  0]
#  [20  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 21.925533294677734
# Mean squared error (MSE) = 1418.28662109375
# Mean absolute percentage error (MAPE) = 197.63963222503662
# Cohen kappa score = 0.0
# Epoch:15/30 AVG Training Loss:1529.160 AVG Val Loss:1767.207
# Custom bins confusion matrix:
# [[49  0  0  0]
#  [ 2  0  0  0]
#  [20  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 21.91236114501953
# Mean squared error (MSE) = 1417.53515625
# Mean absolute percentage error (MAPE) = 202.36341953277588
# Cohen kappa score = 0.0
# Epoch:16/30 AVG Training Loss:1457.143 AVG Val Loss:1319.744
# Custom bins confusion matrix:
# [[49  0  0  0]
#  [ 2  0  0  0]
#  [20  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 21.90196990966797
# Mean squared error (MSE) = 1416.92822265625
# Mean absolute percentage error (MAPE) = 206.1493158340454
# Cohen kappa score = 0.0
# Epoch:17/30 AVG Training Loss:1442.919 AVG Val Loss:1700.995
# Custom bins confusion matrix:
# [[49  0  0  0]
#  [ 2  0  0  0]
#  [20  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 21.89341926574707
# Mean squared error (MSE) = 1416.43798828125
# Mean absolute percentage error (MAPE) = 209.39548015594482
# Cohen kappa score = 0.0
# Epoch:18/30 AVG Training Loss:1461.708 AVG Val Loss:1057.967
# Custom bins confusion matrix:
# [[49  0  0  0]
#  [ 2  0  0  0]
#  [20  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 21.88648223876953
# Mean squared error (MSE) = 1416.04833984375
# Mean absolute percentage error (MAPE) = 211.9598388671875
# Cohen kappa score = 0.0
# Epoch:19/30 AVG Training Loss:1469.208 AVG Val Loss:2064.405
# Custom bins confusion matrix:
# [[49  0  0  0]
#  [ 2  0  0  0]
#  [20  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 21.880876541137695
# Mean squared error (MSE) = 1415.7349853515625
# Mean absolute percentage error (MAPE) = 213.9023780822754
# Cohen kappa score = 0.0
# Epoch:20/30 AVG Training Loss:1578.388 AVG Val Loss:1332.086
# Custom bins confusion matrix:
# [[49  0  0  0]
#  [ 2  0  0  0]
#  [20  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 21.876256942749023
# Mean squared error (MSE) = 1415.4755859375
# Mean absolute percentage error (MAPE) = 215.34242630004883
# Cohen kappa score = 0.0
# Epoch:21/30 AVG Training Loss:1489.859 AVG Val Loss:1308.419
# Custom bins confusion matrix:
# [[49  0  0  0]
#  [ 2  0  0  0]
#  [20  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 21.87247085571289
# Mean squared error (MSE) = 1415.259521484375
# Mean absolute percentage error (MAPE) = 216.3865089416504
# Cohen kappa score = 0.0
# Epoch:22/30 AVG Training Loss:1613.790 AVG Val Loss:1572.424
# Custom bins confusion matrix:
# [[49  0  0  0]
#  [ 2  0  0  0]
#  [20  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 21.869186401367188
# Mean squared error (MSE) = 1415.07177734375
# Mean absolute percentage error (MAPE) = 217.18955039978027
# Cohen kappa score = 0.0
# Epoch:23/30 AVG Training Loss:1401.679 AVG Val Loss:2100.499
# Custom bins confusion matrix:
# [[49  0  0  0]
#  [ 2  0  0  0]
#  [20  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 21.866395950317383
# Mean squared error (MSE) = 1414.9134521484375
# Mean absolute percentage error (MAPE) = 217.78535842895508
# Cohen kappa score = 0.0
# Epoch:24/30 AVG Training Loss:1436.755 AVG Val Loss:1272.106
# Custom bins confusion matrix:
# [[49  0  0  0]
#  [ 2  0  0  0]
#  [20  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 21.86397933959961
# Mean squared error (MSE) = 1414.7750244140625
# Mean absolute percentage error (MAPE) = 218.24538707733154
# Cohen kappa score = 0.0
# Epoch:25/30 AVG Training Loss:1510.792 AVG Val Loss:1058.383
# Custom bins confusion matrix:
# [[49  0  0  0]
#  [ 2  0  0  0]
#  [20  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 21.861881256103516
# Mean squared error (MSE) = 1414.6539306640625
# Mean absolute percentage error (MAPE) = 218.60227584838867
# Cohen kappa score = 0.0
# Epoch:26/30 AVG Training Loss:1400.697 AVG Val Loss:1162.441
# Custom bins confusion matrix:
# [[49  0  0  0]
#  [ 2  0  0  0]
#  [20  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 21.859878540039062
# Mean squared error (MSE) = 1414.5487060546875
# Mean absolute percentage error (MAPE) = 218.89069080352783
# Cohen kappa score = 0.0
# Epoch:27/30 AVG Training Loss:1575.427 AVG Val Loss:1051.534
# Custom bins confusion matrix:
# [[49  0  0  0]
#  [ 2  0  0  0]
#  [20  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 21.85795783996582
# Mean squared error (MSE) = 1414.448974609375
# Mean absolute percentage error (MAPE) = 219.12028789520264
# Cohen kappa score = 0.0
# Epoch:28/30 AVG Training Loss:1465.095 AVG Val Loss:1784.324
# Custom bins confusion matrix:
# [[49  0  0  0]
#  [ 2  0  0  0]
#  [20  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 21.85630226135254
# Mean squared error (MSE) = 1414.36083984375
# Mean absolute percentage error (MAPE) = 219.2983865737915
# Cohen kappa score = 0.0
# Epoch:29/30 AVG Training Loss:1579.519 AVG Val Loss:795.842
# Custom bins confusion matrix:
# [[49  0  0  0]
#  [ 2  0  0  0]
#  [20  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 21.85479736328125
# Mean squared error (MSE) = 1414.279052734375
# Mean absolute percentage error (MAPE) = 219.4469451904297
# Cohen kappa score = 0.0
# Epoch:30/30 AVG Training Loss:1522.116 AVG Val Loss:795.857
# Val Fold 2
# Custom bins confusion matrix:
# [[50  0]
#  [22  0]]
# Mean absolute deviation (MAD) = 22.24042510986328
# Mean squared error (MSE) = 1431.4013671875
# Mean absolute percentage error (MAPE) = 143.58571767807007
# Cohen kappa score = 0.0
# Epoch:1/30 AVG Training Loss:1464.169 AVG Val Loss:2104.411
# Custom bins confusion matrix:
# [[50  0]
#  [22  0]]
# Mean absolute deviation (MAD) = 22.226999282836914
# Mean squared error (MSE) = 1430.126953125
# Mean absolute percentage error (MAPE) = 146.0986852645874
# Cohen kappa score = 0.0
# Epoch:2/30 AVG Training Loss:1464.980 AVG Val Loss:1318.899
# Custom bins confusion matrix:
# [[50  0]
#  [22  0]]
# Mean absolute deviation (MAD) = 22.21341896057129
# Mean squared error (MSE) = 1428.83251953125
# Mean absolute percentage error (MAPE) = 148.61407279968262
# Cohen kappa score = 0.0
# Epoch:3/30 AVG Training Loss:1456.367 AVG Val Loss:805.209
# Custom bins confusion matrix:
# [[50  0]
#  [22  0]]
# Mean absolute deviation (MAD) = 22.19932746887207
# Mean squared error (MSE) = 1427.4920654296875
# Mean absolute percentage error (MAPE) = 151.23543739318848
# Cohen kappa score = 0.0
# Epoch:4/30 AVG Training Loss:1506.096 AVG Val Loss:1576.351
# Custom bins confusion matrix:
# [[50  0]
#  [22  0]]
# Mean absolute deviation (MAD) = 22.18475914001465
# Mean squared error (MSE) = 1426.0997314453125
# Mean absolute percentage error (MAPE) = 153.9773464202881
# Cohen kappa score = 0.0
# Epoch:5/30 AVG Training Loss:1621.918 AVG Val Loss:814.285
# Custom bins confusion matrix:
# [[50  0]
#  [22  0]]
# Mean absolute deviation (MAD) = 22.169544219970703
# Mean squared error (MSE) = 1424.6549072265625
# Mean absolute percentage error (MAPE) = 156.87512159347534
# Cohen kappa score = 0.0
# Epoch:6/30 AVG Training Loss:1414.086 AVG Val Loss:1079.683
# Custom bins confusion matrix:
# [[50  0]
#  [22  0]]
# Mean absolute deviation (MAD) = 22.15387725830078
# Mean squared error (MSE) = 1423.19775390625
# Mean absolute percentage error (MAPE) = 159.91569757461548
# Cohen kappa score = 0.0
# Epoch:7/30 AVG Training Loss:1601.922 AVG Val Loss:808.393
# Custom bins confusion matrix:
# [[50  0]
#  [22  0]]
# Mean absolute deviation (MAD) = 22.137304306030273
# Mean squared error (MSE) = 1421.6849365234375
# Mean absolute percentage error (MAPE) = 163.23904991149902
# Cohen kappa score = 0.0
# Epoch:8/30 AVG Training Loss:1532.430 AVG Val Loss:1324.858
# Custom bins confusion matrix:
# [[50  0]
#  [22  0]]
# Mean absolute deviation (MAD) = 22.1202335357666
# Mean squared error (MSE) = 1420.1925048828125
# Mean absolute percentage error (MAPE) = 166.8354630470276
# Cohen kappa score = 0.0
# Epoch:9/30 AVG Training Loss:1566.838 AVG Val Loss:1061.678
# Custom bins confusion matrix:
# [[50  0]
#  [22  0]]
# Mean absolute deviation (MAD) = 22.102569580078125
# Mean squared error (MSE) = 1418.7283935546875
# Mean absolute percentage error (MAPE) = 170.81761360168457
# Cohen kappa score = 0.0
# Epoch:10/30 AVG Training Loss:1633.814 AVG Val Loss:1566.081
# Custom bins confusion matrix:
# [[50  0]
#  [22  0]]
# Mean absolute deviation (MAD) = 22.08526611328125
# Mean squared error (MSE) = 1417.349609375
# Mean absolute percentage error (MAPE) = 174.9997854232788
# Cohen kappa score = 0.0
# Epoch:11/30 AVG Training Loss:1596.172 AVG Val Loss:1232.145
# Custom bins confusion matrix:
# [[50  0]
#  [22  0]]
# Mean absolute deviation (MAD) = 22.068429946899414
# Mean squared error (MSE) = 1416.096435546875
# Mean absolute percentage error (MAPE) = 179.389488697052
# Cohen kappa score = 0.0
# Epoch:12/30 AVG Training Loss:1492.121 AVG Val Loss:1553.741
# Custom bins confusion matrix:
# [[50  0]
#  [22  0]]
# Mean absolute deviation (MAD) = 22.05363655090332
# Mean squared error (MSE) = 1415.036865234375
# Mean absolute percentage error (MAPE) = 183.67576599121094
# Cohen kappa score = 0.0
# Epoch:13/30 AVG Training Loss:1476.531 AVG Val Loss:1472.915
# Custom bins confusion matrix:
# [[50  0]
#  [22  0]]
# Mean absolute deviation (MAD) = 22.04058074951172
# Mean squared error (MSE) = 1414.16259765625
# Mean absolute percentage error (MAPE) = 187.43290901184082
# Cohen kappa score = 0.0
# Epoch:14/30 AVG Training Loss:1513.930 AVG Val Loss:1307.563
# Custom bins confusion matrix:
# [[50  0]
#  [22  0]]
# Mean absolute deviation (MAD) = 22.02865982055664
# Mean squared error (MSE) = 1413.435546875
# Mean absolute percentage error (MAPE) = 190.59919118881226
# Cohen kappa score = 0.0
# Epoch:15/30 AVG Training Loss:1596.896 AVG Val Loss:1063.621
# Custom bins confusion matrix:
# [[50  0]
#  [22  0]]
# Mean absolute deviation (MAD) = 22.018943786621094
# Mean squared error (MSE) = 1412.843017578125
# Mean absolute percentage error (MAPE) = 193.0142045021057
# Cohen kappa score = 0.0
# Epoch:16/30 AVG Training Loss:1552.358 AVG Val Loss:1300.654
# Custom bins confusion matrix:
# [[50  0]
#  [22  0]]
# Mean absolute deviation (MAD) = 22.01088523864746
# Mean squared error (MSE) = 1412.3778076171875
# Mean absolute percentage error (MAPE) = 194.69850063323975
# Cohen kappa score = 0.0
# Epoch:17/30 AVG Training Loss:1464.966 AVG Val Loss:1563.986
# Custom bins confusion matrix:
# [[50  0]
#  [22  0]]
# Mean absolute deviation (MAD) = 22.004337310791016
# Mean squared error (MSE) = 1412.0113525390625
# Mean absolute percentage error (MAPE) = 195.86999416351318
# Cohen kappa score = 0.0
# Epoch:18/30 AVG Training Loss:1530.424 AVG Val Loss:1825.562
# Custom bins confusion matrix:
# [[50  0]
#  [22  0]]
# Mean absolute deviation (MAD) = 21.99904441833496
# Mean squared error (MSE) = 1411.7139892578125
# Mean absolute percentage error (MAPE) = 196.73199653625488
# Cohen kappa score = 0.0
# Epoch:19/30 AVG Training Loss:1554.652 AVG Val Loss:1286.775
# Custom bins confusion matrix:
# [[50  0]
#  [22  0]]
# Mean absolute deviation (MAD) = 21.9948673248291
# Mean squared error (MSE) = 1411.472412109375
# Mean absolute percentage error (MAPE) = 197.3692536354065
# Cohen kappa score = 0.0
# Epoch:20/30 AVG Training Loss:1551.676 AVG Val Loss:1315.304
# Custom bins confusion matrix:
# [[50  0]
#  [22  0]]
# Mean absolute deviation (MAD) = 21.99163818359375
# Mean squared error (MSE) = 1411.2708740234375
# Mean absolute percentage error (MAPE) = 197.8578805923462
# Cohen kappa score = 0.0
# Epoch:21/30 AVG Training Loss:1516.891 AVG Val Loss:1307.601
# Custom bins confusion matrix:
# [[50  0]
#  [22  0]]
# Mean absolute deviation (MAD) = 21.98893165588379
# Mean squared error (MSE) = 1411.1007080078125
# Mean absolute percentage error (MAPE) = 198.25968742370605
# Cohen kappa score = 0.0
# Epoch:22/30 AVG Training Loss:1551.895 AVG Val Loss:1309.658
# Custom bins confusion matrix:
# [[50  0]
#  [22  0]]
# Mean absolute deviation (MAD) = 21.986780166625977
# Mean squared error (MSE) = 1410.95849609375
# Mean absolute percentage error (MAPE) = 198.58148097991943
# Cohen kappa score = 0.0
# Epoch:23/30 AVG Training Loss:1517.775 AVG Val Loss:1458.315
# Custom bins confusion matrix:
# [[50  0]
#  [22  0]]
# Mean absolute deviation (MAD) = 21.985036849975586
# Mean squared error (MSE) = 1410.8380126953125
# Mean absolute percentage error (MAPE) = 198.85125160217285
# Cohen kappa score = 0.0
# Epoch:24/30 AVG Training Loss:1528.004 AVG Val Loss:1811.135
# Custom bins confusion matrix:
# [[50  0]
#  [22  0]]
# Mean absolute deviation (MAD) = 21.983652114868164
# Mean squared error (MSE) = 1410.7332763671875
# Mean absolute percentage error (MAPE) = 199.07374382019043
# Cohen kappa score = 0.0
# Epoch:25/30 AVG Training Loss:1693.221 AVG Val Loss:2071.323
# Custom bins confusion matrix:
# [[50  0]
#  [22  0]]
# Mean absolute deviation (MAD) = 21.98249053955078
# Mean squared error (MSE) = 1410.6416015625
# Mean absolute percentage error (MAPE) = 199.27215576171875
# Cohen kappa score = 0.0
# Epoch:26/30 AVG Training Loss:1395.427 AVG Val Loss:1575.659
# Custom bins confusion matrix:
# [[50  0]
#  [22  0]]
# Mean absolute deviation (MAD) = 21.981523513793945
# Mean squared error (MSE) = 1410.5618896484375
# Mean absolute percentage error (MAPE) = 199.4443655014038
# Cohen kappa score = 0.0
# Epoch:27/30 AVG Training Loss:1458.644 AVG Val Loss:1063.405
# Custom bins confusion matrix:
# [[50  0]
#  [22  0]]
# Mean absolute deviation (MAD) = 21.980640411376953
# Mean squared error (MSE) = 1410.48828125
# Mean absolute percentage error (MAPE) = 199.61810111999512
# Cohen kappa score = 0.0
# Epoch:28/30 AVG Training Loss:1663.967 AVG Val Loss:793.919
# Custom bins confusion matrix:
# [[50  0]
#  [22  0]]
# Mean absolute deviation (MAD) = 21.979785919189453
# Mean squared error (MSE) = 1410.4150390625
# Mean absolute percentage error (MAPE) = 199.79642629623413
# Cohen kappa score = 0.0
# Epoch:29/30 AVG Training Loss:1485.930 AVG Val Loss:1308.172
# Custom bins confusion matrix:
# [[50  0]
#  [22  0]]
# Mean absolute deviation (MAD) = 21.979026794433594
# Mean squared error (MSE) = 1410.3485107421875
# Mean absolute percentage error (MAPE) = 199.96858835220337
# Cohen kappa score = 0.0
# Epoch:30/30 AVG Training Loss:1517.108 AVG Val Loss:1314.208
# Val Fold 3
# Custom bins confusion matrix:
# [[47  0  0]
#  [22  0  0]
#  [ 3  0  0]]
# Mean absolute deviation (MAD) = 24.617616653442383
# Mean squared error (MSE) = 1622.856201171875
# Mean absolute percentage error (MAPE) = 178.6649465560913
# Cohen kappa score = 0.0
# Epoch:1/30 AVG Training Loss:1471.674 AVG Val Loss:1689.690
# Custom bins confusion matrix:
# [[47  0  0]
#  [22  0  0]
#  [ 3  0  0]]
# Mean absolute deviation (MAD) = 24.605083465576172
# Mean squared error (MSE) = 1621.4840087890625
# Mean absolute percentage error (MAPE) = 181.91388845443726
# Cohen kappa score = 0.0
# Epoch:2/30 AVG Training Loss:1586.543 AVG Val Loss:1724.752
# Custom bins confusion matrix:
# [[47  0  0]
#  [22  0  0]
#  [ 3  0  0]]
# Mean absolute deviation (MAD) = 24.592512130737305
# Mean squared error (MSE) = 1620.1068115234375
# Mean absolute percentage error (MAPE) = 185.04126071929932
# Cohen kappa score = 0.0
# Epoch:3/30 AVG Training Loss:1535.004 AVG Val Loss:1441.341
# Custom bins confusion matrix:
# [[47  0  0]
#  [22  0  0]
#  [ 3  0  0]]
# Mean absolute deviation (MAD) = 24.579912185668945
# Mean squared error (MSE) = 1618.730712890625
# Mean absolute percentage error (MAPE) = 188.26050758361816
# Cohen kappa score = 0.0
# Epoch:4/30 AVG Training Loss:1389.469 AVG Val Loss:1190.782
# Custom bins confusion matrix:
# [[47  0  0]
#  [22  0  0]
#  [ 3  0  0]]
# Mean absolute deviation (MAD) = 24.567163467407227
# Mean squared error (MSE) = 1617.35302734375
# Mean absolute percentage error (MAPE) = 191.61423444747925
# Cohen kappa score = 0.0
# Epoch:5/30 AVG Training Loss:1398.098 AVG Val Loss:1670.835
# Custom bins confusion matrix:
# [[47  0  0]
#  [22  0  0]
#  [ 3  0  0]]
# Mean absolute deviation (MAD) = 24.55394744873047
# Mean squared error (MSE) = 1615.93505859375
# Mean absolute percentage error (MAPE) = 195.09623050689697
# Cohen kappa score = 0.0
# Epoch:6/30 AVG Training Loss:1607.796 AVG Val Loss:2165.130
# Custom bins confusion matrix:
# [[47  0  0]
#  [22  0  0]
#  [ 3  0  0]]
# Mean absolute deviation (MAD) = 24.53980255126953
# Mean squared error (MSE) = 1614.4344482421875
# Mean absolute percentage error (MAPE) = 198.96215200424194
# Cohen kappa score = 0.0
# Epoch:7/30 AVG Training Loss:1463.036 AVG Val Loss:1440.817
# Custom bins confusion matrix:
# [[47  0  0]
#  [22  0  0]
#  [ 3  0  0]]
# Mean absolute deviation (MAD) = 24.525314331054688
# Mean squared error (MSE) = 1612.9266357421875
# Mean absolute percentage error (MAPE) = 203.1912088394165
# Cohen kappa score = 0.0
# Epoch:8/30 AVG Training Loss:1474.281 AVG Val Loss:1415.478
# Custom bins confusion matrix:
# [[47  0  0]
#  [22  0  0]
#  [ 3  0  0]]
# Mean absolute deviation (MAD) = 24.51053810119629
# Mean squared error (MSE) = 1611.4266357421875
# Mean absolute percentage error (MAPE) = 207.88960456848145
# Cohen kappa score = 0.0
# Epoch:9/30 AVG Training Loss:1346.783 AVG Val Loss:1394.062
# Custom bins confusion matrix:
# [[47  0  0]
#  [22  0  0]
#  [ 3  0  0]]
# Mean absolute deviation (MAD) = 24.496206283569336
# Mean squared error (MSE) = 1610.0108642578125
# Mean absolute percentage error (MAPE) = 212.9314422607422
# Cohen kappa score = 0.0
# Epoch:10/30 AVG Training Loss:1442.855 AVG Val Loss:1199.936
# Custom bins confusion matrix:
# [[47  0  0]
#  [22  0  0]
#  [ 3  0  0]]
# Mean absolute deviation (MAD) = 24.48204803466797
# Mean squared error (MSE) = 1608.655029296875
# Mean absolute percentage error (MAPE) = 218.4601068496704
# Cohen kappa score = 0.0
# Epoch:11/30 AVG Training Loss:1501.780 AVG Val Loss:2203.474
# Custom bins confusion matrix:
# [[47  0  0]
#  [22  0  0]
#  [ 3  0  0]]
# Mean absolute deviation (MAD) = 24.468589782714844
# Mean squared error (MSE) = 1607.41455078125
# Mean absolute percentage error (MAPE) = 224.37129020690918
# Cohen kappa score = 0.0
# Epoch:12/30 AVG Training Loss:1405.025 AVG Val Loss:1431.368
# Custom bins confusion matrix:
# [[47  0  0]
#  [22  0  0]
#  [ 3  0  0]]
# Mean absolute deviation (MAD) = 24.45653533935547
# Mean squared error (MSE) = 1606.3367919921875
# Mean absolute percentage error (MAPE) = 230.18488883972168
# Cohen kappa score = 0.0
# Epoch:13/30 AVG Training Loss:1525.150 AVG Val Loss:1294.308
# Custom bins confusion matrix:
# [[47  0  0]
#  [22  0  0]
#  [ 3  0  0]]
# Mean absolute deviation (MAD) = 24.446128845214844
# Mean squared error (MSE) = 1605.4212646484375
# Mean absolute percentage error (MAPE) = 235.52768230438232
# Cohen kappa score = 0.0
# Epoch:14/30 AVG Training Loss:1476.904 AVG Val Loss:1710.533
# Custom bins confusion matrix:
# [[47  0  0]
#  [22  0  0]
#  [ 3  0  0]]
# Mean absolute deviation (MAD) = 24.437610626220703
# Mean squared error (MSE) = 1604.6749267578125
# Mean absolute percentage error (MAPE) = 240.12999534606934
# Cohen kappa score = 0.0
# Epoch:15/30 AVG Training Loss:1456.657 AVG Val Loss:1156.525
# Custom bins confusion matrix:
# [[47  0  0]
#  [22  0  0]
#  [ 3  0  0]]
# Mean absolute deviation (MAD) = 24.431026458740234
# Mean squared error (MSE) = 1604.084228515625
# Mean absolute percentage error (MAPE) = 243.87362003326416
# Cohen kappa score = 0.0
# Epoch:16/30 AVG Training Loss:1563.955 AVG Val Loss:1155.690
# Custom bins confusion matrix:
# [[47  0  0]
#  [22  0  0]
#  [ 3  0  0]]
# Mean absolute deviation (MAD) = 24.425893783569336
# Mean squared error (MSE) = 1603.6048583984375
# Mean absolute percentage error (MAPE) = 247.04785346984863
# Cohen kappa score = 0.0
# Epoch:17/30 AVG Training Loss:1492.882 AVG Val Loss:1417.143
# Custom bins confusion matrix:
# [[47  0  0]
#  [22  0  0]
#  [ 3  0  0]]
# Mean absolute deviation (MAD) = 24.422136306762695
# Mean squared error (MSE) = 1603.228759765625
# Mean absolute percentage error (MAPE) = 249.58720207214355
# Cohen kappa score = 0.0
# Epoch:18/30 AVG Training Loss:1311.377 AVG Val Loss:1434.355
# Custom bins confusion matrix:
# [[47  0  0]
#  [22  0  0]
#  [ 3  0  0]]
# Mean absolute deviation (MAD) = 24.41939353942871
# Mean squared error (MSE) = 1602.93310546875
# Mean absolute percentage error (MAPE) = 251.45936012268066
# Cohen kappa score = 0.0
# Epoch:19/30 AVG Training Loss:1580.292 AVG Val Loss:1886.768
# Custom bins confusion matrix:
# [[47  0  0]
#  [22  0  0]
#  [ 3  0  0]]
# Mean absolute deviation (MAD) = 24.417213439941406
# Mean squared error (MSE) = 1602.6824951171875
# Mean absolute percentage error (MAPE) = 253.00045013427734
# Cohen kappa score = 0.0
# Epoch:20/30 AVG Training Loss:1303.219 AVG Val Loss:2466.488
# Custom bins confusion matrix:
# [[47  0  0]
#  [22  0  0]
#  [ 3  0  0]]
# Mean absolute deviation (MAD) = 24.415508270263672
# Mean squared error (MSE) = 1602.4796142578125
# Mean absolute percentage error (MAPE) = 254.16390895843506
# Cohen kappa score = 0.0
# Epoch:21/30 AVG Training Loss:1373.006 AVG Val Loss:2423.956
# Custom bins confusion matrix:
# [[47  0  0]
#  [22  0  0]
#  [ 3  0  0]]
# Mean absolute deviation (MAD) = 24.41414451599121
# Mean squared error (MSE) = 1602.314208984375
# Mean absolute percentage error (MAPE) = 255.0753355026245
# Cohen kappa score = 0.0
# Epoch:22/30 AVG Training Loss:1494.800 AVG Val Loss:1428.171
# Custom bins confusion matrix:
# [[47  0  0]
#  [22  0  0]
#  [ 3  0  0]]
# Mean absolute deviation (MAD) = 24.412965774536133
# Mean squared error (MSE) = 1602.1715087890625
# Mean absolute percentage error (MAPE) = 255.7924747467041
# Cohen kappa score = 0.0
# Epoch:23/30 AVG Training Loss:1562.927 AVG Val Loss:1551.601
# Custom bins confusion matrix:
# [[47  0  0]
#  [22  0  0]
#  [ 3  0  0]]
# Mean absolute deviation (MAD) = 24.411930084228516
# Mean squared error (MSE) = 1602.0440673828125
# Mean absolute percentage error (MAPE) = 256.3982963562012
# Cohen kappa score = 0.0
# Epoch:24/30 AVG Training Loss:1313.511 AVG Val Loss:1189.932
# Custom bins confusion matrix:
# [[47  0  0]
#  [22  0  0]
#  [ 3  0  0]]
# Mean absolute deviation (MAD) = 24.411012649536133
# Mean squared error (MSE) = 1601.930908203125
# Mean absolute percentage error (MAPE) = 256.9152355194092
# Cohen kappa score = 0.0
# Epoch:25/30 AVG Training Loss:1414.089 AVG Val Loss:1172.990
# Custom bins confusion matrix:
# [[47  0  0]
#  [22  0  0]
#  [ 3  0  0]]
# Mean absolute deviation (MAD) = 24.410194396972656
# Mean squared error (MSE) = 1601.828857421875
# Mean absolute percentage error (MAPE) = 257.40296840667725
# Cohen kappa score = 0.0
# Epoch:26/30 AVG Training Loss:1435.338 AVG Val Loss:1698.624
# Custom bins confusion matrix:
# [[47  0  0]
#  [22  0  0]
#  [ 3  0  0]]
# Mean absolute deviation (MAD) = 24.409515380859375
# Mean squared error (MSE) = 1601.7442626953125
# Mean absolute percentage error (MAPE) = 257.83376693725586
# Cohen kappa score = 0.0
# Epoch:27/30 AVG Training Loss:1430.301 AVG Val Loss:901.584
# Custom bins confusion matrix:
# [[47  0  0]
#  [22  0  0]
#  [ 3  0  0]]
# Mean absolute deviation (MAD) = 24.408893585205078
# Mean squared error (MSE) = 1601.66796875
# Mean absolute percentage error (MAPE) = 258.2120180130005
# Cohen kappa score = 0.0
# Epoch:28/30 AVG Training Loss:1404.925 AVG Val Loss:2192.028
# Custom bins confusion matrix:
# [[47  0  0]
#  [22  0  0]
#  [ 3  0  0]]
# Mean absolute deviation (MAD) = 24.408348083496094
# Mean squared error (MSE) = 1601.602783203125
# Mean absolute percentage error (MAPE) = 258.5097074508667
# Cohen kappa score = 0.0
# Epoch:29/30 AVG Training Loss:1341.656 AVG Val Loss:1693.679
# Custom bins confusion matrix:
# [[47  0  0]
#  [22  0  0]
#  [ 3  0  0]]
# Mean absolute deviation (MAD) = 24.407846450805664
# Mean squared error (MSE) = 1601.5421142578125
# Mean absolute percentage error (MAPE) = 258.78007411956787
# Cohen kappa score = 0.0
# Epoch:30/30 AVG Training Loss:1501.246 AVG Val Loss:1148.038
# Val Fold 4
# Custom bins confusion matrix:
# [[48  0  0  0]
#  [ 2  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 23.786874771118164
# Mean squared error (MSE) = 1528.2198486328125
# Mean absolute percentage error (MAPE) = 160.19660234451294
# Cohen kappa score = 0.0
# Epoch:1/30 AVG Training Loss:1447.134 AVG Val Loss:1921.489
# Custom bins confusion matrix:
# [[48  0  0  0]
#  [ 2  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 23.774091720581055
# Mean squared error (MSE) = 1526.9521484375
# Mean absolute percentage error (MAPE) = 162.29466199874878
# Cohen kappa score = 0.0
# Epoch:2/30 AVG Training Loss:1478.751 AVG Val Loss:1138.594
# Custom bins confusion matrix:
# [[48  0  0  0]
#  [ 2  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 23.760848999023438
# Mean squared error (MSE) = 1525.6282958984375
# Mean absolute percentage error (MAPE) = 164.4056797027588
# Cohen kappa score = 0.0
# Epoch:3/30 AVG Training Loss:1537.395 AVG Val Loss:1469.784
# Custom bins confusion matrix:
# [[48  0  0  0]
#  [ 2  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 23.74714469909668
# Mean squared error (MSE) = 1524.2701416015625
# Mean absolute percentage error (MAPE) = 166.6390299797058
# Cohen kappa score = 0.0
# Epoch:4/30 AVG Training Loss:1427.487 AVG Val Loss:857.834
# Custom bins confusion matrix:
# [[48  0  0  0]
#  [ 2  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 23.73311424255371
# Mean squared error (MSE) = 1522.8995361328125
# Mean absolute percentage error (MAPE) = 169.05384063720703
# Cohen kappa score = 0.0
# Epoch:5/30 AVG Training Loss:1463.864 AVG Val Loss:1153.059
# Custom bins confusion matrix:
# [[48  0  0  0]
#  [ 2  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 23.718671798706055
# Mean squared error (MSE) = 1521.5030517578125
# Mean absolute percentage error (MAPE) = 171.68413400650024
# Cohen kappa score = 0.0
# Epoch:6/30 AVG Training Loss:1488.311 AVG Val Loss:1645.655
# Custom bins confusion matrix:
# [[48  0  0  0]
#  [ 2  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 23.703651428222656
# Mean squared error (MSE) = 1520.0853271484375
# Mean absolute percentage error (MAPE) = 174.63603019714355
# Cohen kappa score = 0.0
# Epoch:7/30 AVG Training Loss:1500.319 AVG Val Loss:1643.040
# Custom bins confusion matrix:
# [[48  0  0  0]
#  [ 2  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 23.688255310058594
# Mean squared error (MSE) = 1518.69482421875
# Mean absolute percentage error (MAPE) = 178.01194190979004
# Cohen kappa score = 0.0
# Epoch:8/30 AVG Training Loss:1348.060 AVG Val Loss:1403.346
# Custom bins confusion matrix:
# [[48  0  0  0]
#  [ 2  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 23.672874450683594
# Mean squared error (MSE) = 1517.3687744140625
# Mean absolute percentage error (MAPE) = 181.7604899406433
# Cohen kappa score = 0.0
# Epoch:9/30 AVG Training Loss:1510.698 AVG Val Loss:1384.322
# Custom bins confusion matrix:
# [[48  0  0  0]
#  [ 2  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 23.65743637084961
# Mean squared error (MSE) = 1516.1146240234375
# Mean absolute percentage error (MAPE) = 185.95420122146606
# Cohen kappa score = 0.0
# Epoch:10/30 AVG Training Loss:1467.524 AVG Val Loss:1345.475
# Custom bins confusion matrix:
# [[48  0  0  0]
#  [ 2  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 23.642486572265625
# Mean squared error (MSE) = 1514.9837646484375
# Mean absolute percentage error (MAPE) = 190.38628339767456
# Cohen kappa score = 0.0
# Epoch:11/30 AVG Training Loss:1549.442 AVG Val Loss:1115.185
# Custom bins confusion matrix:
# [[48  0  0  0]
#  [ 2  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 23.628177642822266
# Mean squared error (MSE) = 1514.01171875
# Mean absolute percentage error (MAPE) = 194.8383092880249
# Cohen kappa score = 0.0
# Epoch:12/30 AVG Training Loss:1400.277 AVG Val Loss:1893.088
# Custom bins confusion matrix:
# [[48  0  0  0]
#  [ 2  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 23.615264892578125
# Mean squared error (MSE) = 1513.2095947265625
# Mean absolute percentage error (MAPE) = 198.72970581054688
# Cohen kappa score = 0.0
# Epoch:13/30 AVG Training Loss:1538.815 AVG Val Loss:1382.330
# Custom bins confusion matrix:
# [[48  0  0  0]
#  [ 2  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 23.603649139404297
# Mean squared error (MSE) = 1512.552978515625
# Mean absolute percentage error (MAPE) = 201.96757316589355
# Cohen kappa score = 0.0
# Epoch:14/30 AVG Training Loss:1584.804 AVG Val Loss:1774.305
# Custom bins confusion matrix:
# [[48  0  0  0]
#  [ 2  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 23.59360694885254
# Mean squared error (MSE) = 1512.015625
# Mean absolute percentage error (MAPE) = 204.54673767089844
# Cohen kappa score = 0.0
# Epoch:15/30 AVG Training Loss:1545.646 AVG Val Loss:1628.961
# Custom bins confusion matrix:
# [[48  0  0  0]
#  [ 2  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 23.585058212280273
# Mean squared error (MSE) = 1511.57666015625
# Mean absolute percentage error (MAPE) = 206.69543743133545
# Cohen kappa score = 0.0
# Epoch:16/30 AVG Training Loss:1487.167 AVG Val Loss:1112.423
# Custom bins confusion matrix:
# [[48  0  0  0]
#  [ 2  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 23.5782413482666
# Mean squared error (MSE) = 1511.21728515625
# Mean absolute percentage error (MAPE) = 208.45739841461182
# Cohen kappa score = 0.0
# Epoch:17/30 AVG Training Loss:1662.328 AVG Val Loss:1642.467
# Custom bins confusion matrix:
# [[48  0  0  0]
#  [ 2  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 23.57276153564453
# Mean squared error (MSE) = 1510.9210205078125
# Mean absolute percentage error (MAPE) = 210.02254486083984
# Cohen kappa score = 0.0
# Epoch:18/30 AVG Training Loss:1521.834 AVG Val Loss:1358.991
# Custom bins confusion matrix:
# [[48  0  0  0]
#  [ 2  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 23.5687255859375
# Mean squared error (MSE) = 1510.677490234375
# Mean absolute percentage error (MAPE) = 211.2379550933838
# Cohen kappa score = 0.0
# Epoch:19/30 AVG Training Loss:1461.425 AVG Val Loss:1556.488
# Custom bins confusion matrix:
# [[48  0  0  0]
#  [ 2  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 23.565513610839844
# Mean squared error (MSE) = 1510.472900390625
# Mean absolute percentage error (MAPE) = 212.3326539993286
# Cohen kappa score = 0.0
# Epoch:20/30 AVG Training Loss:1473.862 AVG Val Loss:1096.880
# Custom bins confusion matrix:
# [[48  0  0  0]
#  [ 2  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 23.563013076782227
# Mean squared error (MSE) = 1510.300537109375
# Mean absolute percentage error (MAPE) = 213.1943941116333
# Cohen kappa score = 0.0
# Epoch:21/30 AVG Training Loss:1484.421 AVG Val Loss:1476.976
# Custom bins confusion matrix:
# [[48  0  0  0]
#  [ 2  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 23.5610294342041
# Mean squared error (MSE) = 1510.154052734375
# Mean absolute percentage error (MAPE) = 213.9244556427002
# Cohen kappa score = 0.0
# Epoch:22/30 AVG Training Loss:1369.613 AVG Val Loss:1387.868
# Custom bins confusion matrix:
# [[48  0  0  0]
#  [ 2  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 23.55941390991211
# Mean squared error (MSE) = 1510.029052734375
# Mean absolute percentage error (MAPE) = 214.5840883255005
# Cohen kappa score = 0.0
# Epoch:23/30 AVG Training Loss:1430.933 AVG Val Loss:1899.477
# Custom bins confusion matrix:
# [[48  0  0  0]
#  [ 2  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 23.558021545410156
# Mean squared error (MSE) = 1509.9173583984375
# Mean absolute percentage error (MAPE) = 215.19033908843994
# Cohen kappa score = 0.0
# Epoch:24/30 AVG Training Loss:1518.598 AVG Val Loss:1395.557
# Custom bins confusion matrix:
# [[48  0  0  0]
#  [ 2  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 23.556739807128906
# Mean squared error (MSE) = 1509.8123779296875
# Mean absolute percentage error (MAPE) = 215.90232849121094
# Cohen kappa score = 0.0
# Epoch:25/30 AVG Training Loss:1402.787 AVG Val Loss:1942.538
# Custom bins confusion matrix:
# [[48  0  0  0]
#  [ 2  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 23.55569076538086
# Mean squared error (MSE) = 1509.7237548828125
# Mean absolute percentage error (MAPE) = 216.55426025390625
# Cohen kappa score = 0.0
# Epoch:26/30 AVG Training Loss:1556.928 AVG Val Loss:851.301
# Custom bins confusion matrix:
# [[48  0  0  0]
#  [ 2  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 23.55476951599121
# Mean squared error (MSE) = 1509.64208984375
# Mean absolute percentage error (MAPE) = 217.0297384262085
# Cohen kappa score = 0.0
# Epoch:27/30 AVG Training Loss:1494.103 AVG Val Loss:1490.440
# Custom bins confusion matrix:
# [[48  0  0  0]
#  [ 2  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 23.553958892822266
# Mean squared error (MSE) = 1509.5694580078125
# Mean absolute percentage error (MAPE) = 217.44134426116943
# Cohen kappa score = 0.0
# Epoch:28/30 AVG Training Loss:1397.697 AVG Val Loss:1532.763
# Custom bins confusion matrix:
# [[48  0  0  0]
#  [ 2  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 23.553241729736328
# Mean squared error (MSE) = 1509.5023193359375
# Mean absolute percentage error (MAPE) = 217.83299446105957
# Cohen kappa score = 0.0
# Epoch:29/30 AVG Training Loss:1458.138 AVG Val Loss:1132.073
# Custom bins confusion matrix:
# [[48  0  0  0]
#  [ 2  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 23.552608489990234
# Mean squared error (MSE) = 1509.44189453125
# Mean absolute percentage error (MAPE) = 218.13623905181885
# Cohen kappa score = 0.0
# Epoch:30/30 AVG Training Loss:1405.750 AVG Val Loss:1902.877
# Epoch:1/30 AVG MAPE:157.743
# Epoch:2/30 AVG MAPE:160.306
# Epoch:3/30 AVG MAPE:162.862
# Epoch:4/30 AVG MAPE:165.521
# Epoch:5/30 AVG MAPE:168.310
# Epoch:6/30 AVG MAPE:171.258
# Epoch:7/30 AVG MAPE:174.459
# Epoch:8/30 AVG MAPE:177.986
# Epoch:9/30 AVG MAPE:181.846
# Epoch:10/30 AVG MAPE:186.042
# Epoch:11/30 AVG MAPE:190.575
# Epoch:12/30 AVG MAPE:195.349
# Epoch:13/30 AVG MAPE:200.043
# Epoch:14/30 AVG MAPE:204.382
# Epoch:15/30 AVG MAPE:208.229
# Epoch:16/30 AVG MAPE:211.487
# Epoch:17/30 AVG MAPE:214.088
# Epoch:18/30 AVG MAPE:216.219
# Epoch:19/30 AVG MAPE:217.847
# Epoch:20/30 AVG MAPE:219.151
# Epoch:21/30 AVG MAPE:220.140
# Epoch:22/30 AVG MAPE:220.911
# Epoch:23/30 AVG MAPE:221.537
# Epoch:24/30 AVG MAPE:222.056
# Epoch:25/30 AVG MAPE:222.534
# Epoch:26/30 AVG MAPE:222.958
# Epoch:27/30 AVG MAPE:223.300
# Epoch:28/30 AVG MAPE:223.598
# Epoch:29/30 AVG MAPE:223.859
# Epoch:30/30 AVG MAPE:224.083
# Best epoch: 30 Best performance: 224.08296167850494
# Begin to evaluate the best model on test set
# Epoch:1/30 AVG Training Loss:2092.623
# Epoch:2/30 AVG Training Loss:2068.259
# Epoch:3/30 AVG Training Loss:2048.708
# Epoch:4/30 AVG Training Loss:2073.424
# Epoch:5/30 AVG Training Loss:2064.622
# Epoch:6/30 AVG Training Loss:2092.684
# Epoch:7/30 AVG Training Loss:2030.539
# Epoch:8/30 AVG Training Loss:2003.898
# Epoch:9/30 AVG Training Loss:2060.253
# Epoch:10/30 AVG Training Loss:2076.108
# Epoch:11/30 AVG Training Loss:2049.741
# Epoch:12/30 AVG Training Loss:2062.959
# Epoch:13/30 AVG Training Loss:2004.093
# Epoch:14/30 AVG Training Loss:2028.786
# Epoch:15/30 AVG Training Loss:2104.509
# Epoch:16/30 AVG Training Loss:2080.291
# Epoch:17/30 AVG Training Loss:2016.960
# Epoch:18/30 AVG Training Loss:2144.720
# Epoch:19/30 AVG Training Loss:2105.981
# Epoch:20/30 AVG Training Loss:2058.307
# Epoch:21/30 AVG Training Loss:2082.401
# Epoch:22/30 AVG Training Loss:2148.317
# Epoch:23/30 AVG Training Loss:2039.249
# Epoch:24/30 AVG Training Loss:2051.921
# Epoch:25/30 AVG Training Loss:2105.522
# Epoch:26/30 AVG Training Loss:1996.831
# Epoch:27/30 AVG Training Loss:2002.034
# Epoch:28/30 AVG Training Loss:2029.911
# Epoch:29/30 AVG Training Loss:2036.445
# Epoch:30/30 AVG Training Loss:2103.769
# Custom bins confusion matrix:
# [[38  0  0]
#  [ 2  0  0]
#  [33  0  0]]
# Mean absolute deviation (MAD) = 31.261621475219727
# Mean squared error (MSE) = 2026.8221435546875
# Mean absolute percentage error (MAPE) = 182.11617469787598
# Cohen kappa score = 0.0
# Performance on test set 1: MAD = 182.11617469787598, MSE = 2026.8221435546875, MAPE = 182.11617469787598
# ====== Test Fold 2 ======
# Val Fold 1
# Custom bins confusion matrix:
# [[50  0  0  0]
#  [ 1  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 22.632043838500977
# Mean squared error (MSE) = 1452.94970703125
# Mean absolute percentage error (MAPE) = 154.62218523025513
# Cohen kappa score = 0.0
# Epoch:1/30 AVG Training Loss:1467.643 AVG Val Loss:2003.865
# Custom bins confusion matrix:
# [[50  0  0  0]
#  [ 1  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 22.621868133544922
# Mean squared error (MSE) = 1451.8770751953125
# Mean absolute percentage error (MAPE) = 156.90068006515503
# Cohen kappa score = 0.0
# Epoch:2/30 AVG Training Loss:1465.519 AVG Val Loss:1506.984
# Custom bins confusion matrix:
# [[50  0  0  0]
#  [ 1  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 22.61182403564453
# Mean squared error (MSE) = 1450.7891845703125
# Mean absolute percentage error (MAPE) = 159.07251834869385
# Cohen kappa score = 0.0
# Epoch:3/30 AVG Training Loss:1539.358 AVG Val Loss:1276.112
# Custom bins confusion matrix:
# [[50  0  0  0]
#  [ 1  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 22.601945877075195
# Mean squared error (MSE) = 1449.697998046875
# Mean absolute percentage error (MAPE) = 161.26538515090942
# Cohen kappa score = 0.0
# Epoch:4/30 AVG Training Loss:1476.037 AVG Val Loss:1069.564
# Custom bins confusion matrix:
# [[50  0  0  0]
#  [ 1  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 22.592119216918945
# Mean squared error (MSE) = 1448.6160888671875
# Mean absolute percentage error (MAPE) = 163.48224878311157
# Cohen kappa score = 0.0
# Epoch:5/30 AVG Training Loss:1572.101 AVG Val Loss:1509.841
# Custom bins confusion matrix:
# [[50  0  0  0]
#  [ 1  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 22.582040786743164
# Mean squared error (MSE) = 1447.505615234375
# Mean absolute percentage error (MAPE) = 165.7408356666565
# Cohen kappa score = 0.0
# Epoch:6/30 AVG Training Loss:1625.485 AVG Val Loss:1076.059
# Custom bins confusion matrix:
# [[50  0  0  0]
#  [ 1  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 22.571748733520508
# Mean squared error (MSE) = 1446.342041015625
# Mean absolute percentage error (MAPE) = 168.11925172805786
# Cohen kappa score = 0.0
# Epoch:7/30 AVG Training Loss:1552.647 AVG Val Loss:1279.630
# Custom bins confusion matrix:
# [[50  0  0  0]
#  [ 1  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 22.56139373779297
# Mean squared error (MSE) = 1445.15234375
# Mean absolute percentage error (MAPE) = 170.56964635849
# Cohen kappa score = 0.0
# Epoch:8/30 AVG Training Loss:1479.343 AVG Val Loss:1727.356
# Custom bins confusion matrix:
# [[50  0  0  0]
#  [ 1  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 22.550935745239258
# Mean squared error (MSE) = 1443.9737548828125
# Mean absolute percentage error (MAPE) = 173.23951721191406
# Cohen kappa score = 0.0
# Epoch:9/30 AVG Training Loss:1639.020 AVG Val Loss:1738.317
# Custom bins confusion matrix:
# [[50  0  0  0]
#  [ 1  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 22.540199279785156
# Mean squared error (MSE) = 1442.767578125
# Mean absolute percentage error (MAPE) = 176.15292072296143
# Cohen kappa score = 0.0
# Epoch:10/30 AVG Training Loss:1550.201 AVG Val Loss:1656.816
# Custom bins confusion matrix:
# [[50  0  0  0]
#  [ 1  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 22.529674530029297
# Mean squared error (MSE) = 1441.5869140625
# Mean absolute percentage error (MAPE) = 179.24715280532837
# Cohen kappa score = 0.0
# Epoch:11/30 AVG Training Loss:1595.217 AVG Val Loss:1455.035
# Custom bins confusion matrix:
# [[50  0  0  0]
#  [ 1  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 22.519426345825195
# Mean squared error (MSE) = 1440.4608154296875
# Mean absolute percentage error (MAPE) = 182.5249433517456
# Cohen kappa score = 0.0
# Epoch:12/30 AVG Training Loss:1598.199 AVG Val Loss:1747.790
# Custom bins confusion matrix:
# [[50  0  0  0]
#  [ 1  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 22.509309768676758
# Mean squared error (MSE) = 1439.45947265625
# Mean absolute percentage error (MAPE) = 186.3892674446106
# Cohen kappa score = 0.0
# Epoch:13/30 AVG Training Loss:1622.036 AVG Val Loss:1230.883
# Custom bins confusion matrix:
# [[50  0  0  0]
#  [ 1  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 22.4997615814209
# Mean squared error (MSE) = 1438.5762939453125
# Mean absolute percentage error (MAPE) = 190.54958820343018
# Cohen kappa score = 0.0
# Epoch:14/30 AVG Training Loss:1523.292 AVG Val Loss:1055.181
# Custom bins confusion matrix:
# [[50  0  0  0]
#  [ 1  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 22.490386962890625
# Mean squared error (MSE) = 1437.8177490234375
# Mean absolute percentage error (MAPE) = 195.24145126342773
# Cohen kappa score = 0.0
# Epoch:15/30 AVG Training Loss:1605.340 AVG Val Loss:1438.772
# Custom bins confusion matrix:
# [[50  0  0  0]
#  [ 1  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 22.481061935424805
# Mean squared error (MSE) = 1437.1646728515625
# Mean absolute percentage error (MAPE) = 200.58467388153076
# Cohen kappa score = 0.0
# Epoch:16/30 AVG Training Loss:1502.075 AVG Val Loss:832.217
# Custom bins confusion matrix:
# [[50  0  0  0]
#  [ 1  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 22.47265625
# Mean squared error (MSE) = 1436.619140625
# Mean absolute percentage error (MAPE) = 205.84838390350342
# Cohen kappa score = 0.0
# Epoch:17/30 AVG Training Loss:1543.837 AVG Val Loss:1288.874
# Custom bins confusion matrix:
# [[50  0  0  0]
#  [ 1  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 22.46442985534668
# Mean squared error (MSE) = 1436.143798828125
# Mean absolute percentage error (MAPE) = 211.05237007141113
# Cohen kappa score = 0.0
# Epoch:18/30 AVG Training Loss:1651.129 AVG Val Loss:1262.467
# Custom bins confusion matrix:
# [[50  0  0  0]
#  [ 1  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 22.45616912841797
# Mean squared error (MSE) = 1435.7239990234375
# Mean absolute percentage error (MAPE) = 215.77718257904053
# Cohen kappa score = 0.0
# Epoch:19/30 AVG Training Loss:1557.186 AVG Val Loss:1293.138
# Custom bins confusion matrix:
# [[50  0  0  0]
#  [ 1  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 22.447891235351562
# Mean squared error (MSE) = 1435.364013671875
# Mean absolute percentage error (MAPE) = 219.62995529174805
# Cohen kappa score = 0.0
# Epoch:20/30 AVG Training Loss:1463.732 AVG Val Loss:1508.281
# Custom bins confusion matrix:
# [[50  0  0  0]
#  [ 1  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 22.439350128173828
# Mean squared error (MSE) = 1435.04833984375
# Mean absolute percentage error (MAPE) = 222.6569414138794
# Cohen kappa score = 0.0
# Epoch:21/30 AVG Training Loss:1626.722 AVG Val Loss:1629.635
# Custom bins confusion matrix:
# [[50  0  0  0]
#  [ 1  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 22.43105125427246
# Mean squared error (MSE) = 1434.7674560546875
# Mean absolute percentage error (MAPE) = 224.9527931213379
# Cohen kappa score = 0.0
# Epoch:22/30 AVG Training Loss:1497.253 AVG Val Loss:1186.700
# Custom bins confusion matrix:
# [[50  0  0  0]
#  [ 1  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 22.423809051513672
# Mean squared error (MSE) = 1434.5264892578125
# Mean absolute percentage error (MAPE) = 226.6404151916504
# Cohen kappa score = 0.0
# Epoch:23/30 AVG Training Loss:1523.877 AVG Val Loss:1259.709
# Custom bins confusion matrix:
# [[50  0  0  0]
#  [ 1  0  0  0]
#  [21  0  0  0]
#  [ 1  0  0  0]]
# Mean absolute deviation (MAD) = 22.417699813842773
# Mean squared error (MSE) = 1434.3193359375
# Mean absolute percentage error (MAPE) = 227.9322624206543
# ...
# Cohen kappa score = 0.0
# Epoch:16/30 AVG Training Loss:1482.438 AVG Val Loss:1634.927
# Custom bins confusion matrix:
# [[48  0]
#  [24  0]]
# Mean absolute deviation (MAD) = 23.865922927856445
# Mean squared error (MSE) = 1561.48046875
# Mean absolute percentage error (MAPE) = 240.4090404510498
# Cohen kappa score = 0.0
# Epoch:17/30 AVG Training Loss:1453.751 AVG Val Loss:2151.156
# Custom bins confusion matrix:
# [[48  0]
#  [24  0]]
# Mean absolute deviation (MAD) = 23.859682083129883
# Mean squared error (MSE) = 1560.9744873046875
# Mean absolute percentage error (MAPE) = 243.7088966369629
# Cohen kappa score = 0.0
# Epoch:18/30 AVG Training Loss:1465.770 AVG Val Loss:1644.271
# Custom bins confusion matrix:
# [[48  0]
#  [24  0]]
# Mean absolute deviation (MAD) = 23.85504150390625
# Mean squared error (MSE) = 1560.56640625
# Mean absolute percentage error (MAPE) = 246.3284730911255
# Cohen kappa score = 0.0
# Epoch:19/30 AVG Training Loss:1463.969 AVG Val Loss:1392.202
# Custom bins confusion matrix:
# [[48  0]
#  [24  0]]
# Mean absolute deviation (MAD) = 23.851667404174805
# Mean squared error (MSE) = 1560.22509765625
# Mean absolute percentage error (MAPE) = 248.70200157165527
# Cohen kappa score = 0.0
# Epoch:20/30 AVG Training Loss:1510.364 AVG Val Loss:1620.923
# Custom bins confusion matrix:
# [[48  0]
#  [24  0]]
# Mean absolute deviation (MAD) = 23.849403381347656
# Mean squared error (MSE) = 1559.944580078125
# Mean absolute percentage error (MAPE) = 250.7866621017456
# Cohen kappa score = 0.0
# Epoch:21/30 AVG Training Loss:1462.167 AVG Val Loss:1134.840
# Custom bins confusion matrix:
# [[48  0]
#  [24  0]]
# Mean absolute deviation (MAD) = 23.847965240478516
# Mean squared error (MSE) = 1559.7073974609375
# Mean absolute percentage error (MAPE) = 252.68771648406982
# Cohen kappa score = 0.0
# Epoch:22/30 AVG Training Loss:1515.805 AVG Val Loss:1363.008
# Custom bins confusion matrix:
# [[48  0]
#  [24  0]]
# Mean absolute deviation (MAD) = 23.847007751464844
# Mean squared error (MSE) = 1559.5045166015625
# Mean absolute percentage error (MAPE) = 254.32653427124023
# Cohen kappa score = 0.0
# Epoch:23/30 AVG Training Loss:1511.571 AVG Val Loss:1398.327
# Custom bins confusion matrix:
# [[48  0]
#  [24  0]]
# Mean absolute deviation (MAD) = 23.846336364746094
# Mean squared error (MSE) = 1559.331787109375
# Mean absolute percentage error (MAPE) = 255.67359924316406
# Cohen kappa score = 0.0
# Epoch:24/30 AVG Training Loss:1454.024 AVG Val Loss:1133.769
# Custom bins confusion matrix:
# [[48  0]
#  [24  0]]
# Mean absolute deviation (MAD) = 23.845829010009766
# Mean squared error (MSE) = 1559.1885986328125
# Mean absolute percentage error (MAPE) = 256.73553943634033
# Cohen kappa score = 0.0
# Epoch:25/30 AVG Training Loss:1540.147 AVG Val Loss:1408.020
# Custom bins confusion matrix:
# [[48  0]
#  [24  0]]
# Mean absolute deviation (MAD) = 23.845407485961914
# Mean squared error (MSE) = 1559.06494140625
# Mean absolute percentage error (MAPE) = 257.60960578918457
# Cohen kappa score = 0.0
# Epoch:26/30 AVG Training Loss:1360.968 AVG Val Loss:1927.208
# Custom bins confusion matrix:
# [[48  0]
#  [24  0]]
# Mean absolute deviation (MAD) = 23.845069885253906
# Mean squared error (MSE) = 1558.9617919921875
# Mean absolute percentage error (MAPE) = 258.3044767379761
# Cohen kappa score = 0.0
# Epoch:27/30 AVG Training Loss:1376.147 AVG Val Loss:1909.967
# Custom bins confusion matrix:
# [[48  0]
#  [24  0]]
# Mean absolute deviation (MAD) = 23.844972610473633
# Mean squared error (MSE) = 1558.8680419921875
# Mean absolute percentage error (MAPE) = 259.13994312286377
# Cohen kappa score = 0.0
# Epoch:28/30 AVG Training Loss:1508.887 AVG Val Loss:1390.728
# Custom bins confusion matrix:
# [[48  0]
#  [24  0]]
# Mean absolute deviation (MAD) = 23.84486961364746
# Mean squared error (MSE) = 1558.78466796875
# Mean absolute percentage error (MAPE) = 259.84480381011963
# Cohen kappa score = 0.0
# Epoch:29/30 AVG Training Loss:1450.538 AVG Val Loss:1615.732
# Custom bins confusion matrix:
# [[48  0]
#  [24  0]]
# Mean absolute deviation (MAD) = 23.84471893310547
# Mean squared error (MSE) = 1558.712890625
# Mean absolute percentage error (MAPE) = 260.3729724884033
# Cohen kappa score = 0.0
# Epoch:30/30 AVG Training Loss:1365.556 AVG Val Loss:1385.614
# Val Fold 4
# Custom bins confusion matrix:
# [[46  0  0]
#  [ 2  0  0]
#  [24  0  0]]
# Mean absolute deviation (MAD) = 25.11219596862793
# Mean squared error (MSE) = 1633.8873291015625
# Mean absolute percentage error (MAPE) = 154.1144847869873
# Cohen kappa score = 0.0
# Epoch:1/30 AVG Training Loss:1426.714 AVG Val Loss:1689.499
# Custom bins confusion matrix:
# [[46  0  0]
#  [ 2  0  0]
#  [24  0  0]]
# Mean absolute deviation (MAD) = 25.098377227783203
# Mean squared error (MSE) = 1632.6400146484375
# Mean absolute percentage error (MAPE) = 156.71030282974243
# Cohen kappa score = 0.0
# Epoch:2/30 AVG Training Loss:1541.354 AVG Val Loss:2239.872
# Custom bins confusion matrix:
# [[46  0  0]
#  [ 2  0  0]
#  [24  0  0]]
# Mean absolute deviation (MAD) = 25.083852767944336
# Mean squared error (MSE) = 1631.3104248046875
# Mean absolute percentage error (MAPE) = 159.347665309906
# Cohen kappa score = 0.0
# Epoch:3/30 AVG Training Loss:1512.740 AVG Val Loss:1289.275
# Custom bins confusion matrix:
# [[46  0  0]
#  [ 2  0  0]
#  [24  0  0]]
# Mean absolute deviation (MAD) = 25.068769454956055
# Mean squared error (MSE) = 1629.9166259765625
# Mean absolute percentage error (MAPE) = 162.022602558136
# Cohen kappa score = 0.0
# Epoch:4/30 AVG Training Loss:1527.761 AVG Val Loss:1679.782
# Custom bins confusion matrix:
# [[46  0  0]
#  [ 2  0  0]
#  [24  0  0]]
# Mean absolute deviation (MAD) = 25.05277442932129
# Mean squared error (MSE) = 1628.4300537109375
# Mean absolute percentage error (MAPE) = 164.84310626983643
# Cohen kappa score = 0.0
# Epoch:5/30 AVG Training Loss:1366.414 AVG Val Loss:1298.805
# Custom bins confusion matrix:
# [[46  0  0]
#  [ 2  0  0]
#  [24  0  0]]
# Mean absolute deviation (MAD) = 25.036237716674805
# Mean squared error (MSE) = 1626.8782958984375
# Mean absolute percentage error (MAPE) = 167.73055791854858
# Cohen kappa score = 0.0
# Epoch:6/30 AVG Training Loss:1517.798 AVG Val Loss:1156.417
# Custom bins confusion matrix:
# [[46  0  0]
#  [ 2  0  0]
#  [24  0  0]]
# Mean absolute deviation (MAD) = 25.01850128173828
# Mean squared error (MSE) = 1625.20361328125
# Mean absolute percentage error (MAPE) = 170.8212375640869
# Cohen kappa score = 0.0
# Epoch:7/30 AVG Training Loss:1469.431 AVG Val Loss:914.668
# Custom bins confusion matrix:
# [[46  0  0]
#  [ 2  0  0]
#  [24  0  0]]
# Mean absolute deviation (MAD) = 24.9996280670166
# Mean squared error (MSE) = 1623.44140625
# Mean absolute percentage error (MAPE) = 174.22088384628296
# Cohen kappa score = 0.0
# Epoch:8/30 AVG Training Loss:1361.293 AVG Val Loss:1438.601
# Custom bins confusion matrix:
# [[46  0  0]
#  [ 2  0  0]
#  [24  0  0]]
# Mean absolute deviation (MAD) = 24.980180740356445
# Mean squared error (MSE) = 1621.6458740234375
# Mean absolute percentage error (MAPE) = 177.8126835823059
# Cohen kappa score = 0.0
# Epoch:9/30 AVG Training Loss:1446.592 AVG Val Loss:1586.681
# Custom bins confusion matrix:
# [[46  0  0]
#  [ 2  0  0]
#  [24  0  0]]
# Mean absolute deviation (MAD) = 24.960500717163086
# Mean squared error (MSE) = 1619.8914794921875
# Mean absolute percentage error (MAPE) = 181.6831350326538
# Cohen kappa score = 0.0
# Epoch:10/30 AVG Training Loss:1539.631 AVG Val Loss:1944.972
# Custom bins confusion matrix:
# [[46  0  0]
#  [ 2  0  0]
#  [24  0  0]]
# Mean absolute deviation (MAD) = 24.940874099731445
# Mean squared error (MSE) = 1618.2318115234375
# Mean absolute percentage error (MAPE) = 185.8033299446106
# Cohen kappa score = 0.0
# Epoch:11/30 AVG Training Loss:1529.667 AVG Val Loss:1942.008
# Custom bins confusion matrix:
# [[46  0  0]
#  [ 2  0  0]
#  [24  0  0]]
# Mean absolute deviation (MAD) = 24.922359466552734
# Mean squared error (MSE) = 1616.76953125
# Mean absolute percentage error (MAPE) = 189.95717763900757
# Cohen kappa score = 0.0
# Epoch:12/30 AVG Training Loss:1432.288 AVG Val Loss:1212.443
# Custom bins confusion matrix:
# [[46  0  0]
#  [ 2  0  0]
#  [24  0  0]]
# Mean absolute deviation (MAD) = 24.90601348876953
# Mean squared error (MSE) = 1615.5701904296875
# Mean absolute percentage error (MAPE) = 193.76055002212524
# Cohen kappa score = 0.0
# Epoch:13/30 AVG Training Loss:1424.854 AVG Val Loss:2274.928
# Custom bins confusion matrix:
# [[46  0  0]
#  [ 2  0  0]
#  [24  0  0]]
# Mean absolute deviation (MAD) = 24.892215728759766
# Mean squared error (MSE) = 1614.603515625
# Mean absolute percentage error (MAPE) = 196.9104290008545
# Cohen kappa score = 0.0
# Epoch:14/30 AVG Training Loss:1499.747 AVG Val Loss:1408.171
# Custom bins confusion matrix:
# [[46  0  0]
#  [ 2  0  0]
#  [24  0  0]]
# Mean absolute deviation (MAD) = 24.880952835083008
# Mean squared error (MSE) = 1613.833251953125
# Mean absolute percentage error (MAPE) = 199.42291975021362
# Cohen kappa score = 0.0
# Epoch:15/30 AVG Training Loss:1402.984 AVG Val Loss:1879.882
# Custom bins confusion matrix:
# [[46  0  0]
#  [ 2  0  0]
#  [24  0  0]]
# Mean absolute deviation (MAD) = 24.871809005737305
# Mean squared error (MSE) = 1613.2276611328125
# Mean absolute percentage error (MAPE) = 201.49784088134766
# Cohen kappa score = 0.0
# Epoch:16/30 AVG Training Loss:1479.481 AVG Val Loss:1161.450
# Custom bins confusion matrix:
# [[46  0  0]
#  [ 2  0  0]
#  [24  0  0]]
# Mean absolute deviation (MAD) = 24.864486694335938
# Mean squared error (MSE) = 1612.745361328125
# Mean absolute percentage error (MAPE) = 203.1909465789795
# Cohen kappa score = 0.0
# Epoch:17/30 AVG Training Loss:1383.178 AVG Val Loss:1683.882
# Custom bins confusion matrix:
# [[46  0  0]
#  [ 2  0  0]
#  [24  0  0]]
# Mean absolute deviation (MAD) = 24.858856201171875
# Mean squared error (MSE) = 1612.3604736328125
# Mean absolute percentage error (MAPE) = 204.51741218566895
# Cohen kappa score = 0.0
# Epoch:18/30 AVG Training Loss:1455.833 AVG Val Loss:1444.761
# Custom bins confusion matrix:
# [[46  0  0]
#  [ 2  0  0]
#  [24  0  0]]
# Mean absolute deviation (MAD) = 24.854318618774414
# Mean squared error (MSE) = 1612.0345458984375
# Mean absolute percentage error (MAPE) = 205.60259819030762
# Cohen kappa score = 0.0
# Epoch:19/30 AVG Training Loss:1483.325 AVG Val Loss:2287.523
# Custom bins confusion matrix:
# [[46  0  0]
#  [ 2  0  0]
#  [24  0  0]]
# Mean absolute deviation (MAD) = 24.8505859375
# Mean squared error (MSE) = 1611.76806640625
# Mean absolute percentage error (MAPE) = 206.55763149261475
# Cohen kappa score = 0.0
# Epoch:20/30 AVG Training Loss:1563.591 AVG Val Loss:1145.485
# Custom bins confusion matrix:
# [[46  0  0]
#  [ 2  0  0]
#  [24  0  0]]
# Mean absolute deviation (MAD) = 24.847482681274414
# Mean squared error (MSE) = 1611.5406494140625
# Mean absolute percentage error (MAPE) = 207.37595558166504
# Cohen kappa score = 0.0
# Epoch:21/30 AVG Training Loss:1527.647 AVG Val Loss:1951.062
# Custom bins confusion matrix:
# [[46  0  0]
#  [ 2  0  0]
#  [24  0  0]]
# Mean absolute deviation (MAD) = 24.844921112060547
# Mean squared error (MSE) = 1611.35205078125
# Mean absolute percentage error (MAPE) = 208.0742359161377
# Cohen kappa score = 0.0
# Epoch:22/30 AVG Training Loss:1465.420 AVG Val Loss:1168.886
# Custom bins confusion matrix:
# [[46  0  0]
#  [ 2  0  0]
#  [24  0  0]]
# Mean absolute deviation (MAD) = 24.842805862426758
# Mean squared error (MSE) = 1611.193115234375
# Mean absolute percentage error (MAPE) = 208.66177082061768
# Cohen kappa score = 0.0
# Epoch:23/30 AVG Training Loss:1612.869 AVG Val Loss:1605.670
# Custom bins confusion matrix:
# [[46  0  0]
#  [ 2  0  0]
#  [24  0  0]]
# Mean absolute deviation (MAD) = 24.840892791748047
# Mean squared error (MSE) = 1611.043212890625
# Mean absolute percentage error (MAPE) = 209.16740894317627
# Cohen kappa score = 0.0
# Epoch:24/30 AVG Training Loss:1468.428 AVG Val Loss:1613.001
# Custom bins confusion matrix:
# [[46  0  0]
#  [ 2  0  0]
#  [24  0  0]]
# Mean absolute deviation (MAD) = 24.839256286621094
# Mean squared error (MSE) = 1610.910400390625
# Mean absolute percentage error (MAPE) = 209.58664417266846
# Cohen kappa score = 0.0
# Epoch:25/30 AVG Training Loss:1376.268 AVG Val Loss:1658.268
# Custom bins confusion matrix:
# [[46  0  0]
#  [ 2  0  0]
#  [24  0  0]]
# Mean absolute deviation (MAD) = 24.83774185180664
# Mean squared error (MSE) = 1610.7821044921875
# Mean absolute percentage error (MAPE) = 209.95326042175293
# Cohen kappa score = 0.0
# Epoch:26/30 AVG Training Loss:1399.173 AVG Val Loss:1614.676
# Custom bins confusion matrix:
# [[46  0  0]
#  [ 2  0  0]
#  [24  0  0]]
# Mean absolute deviation (MAD) = 24.836406707763672
# Mean squared error (MSE) = 1610.67236328125
# Mean absolute percentage error (MAPE) = 210.27629375457764
# Cohen kappa score = 0.0
# Epoch:27/30 AVG Training Loss:1356.763 AVG Val Loss:1428.290
# Custom bins confusion matrix:
# [[46  0  0]
#  [ 2  0  0]
#  [24  0  0]]
# Mean absolute deviation (MAD) = 24.83523178100586
# Mean squared error (MSE) = 1610.5762939453125
# Mean absolute percentage error (MAPE) = 210.55645942687988
# Cohen kappa score = 0.0
# Epoch:28/30 AVG Training Loss:1464.357 AVG Val Loss:1681.028
# Custom bins confusion matrix:
# [[46  0  0]
#  [ 2  0  0]
#  [24  0  0]]
# Mean absolute deviation (MAD) = 24.83416748046875
# Mean squared error (MSE) = 1610.4891357421875
# Mean absolute percentage error (MAPE) = 210.80565452575684
# Cohen kappa score = 0.0
# Epoch:29/30 AVG Training Loss:1449.930 AVG Val Loss:1169.471
# Custom bins confusion matrix:
# [[46  0  0]
#  [ 2  0  0]
#  [24  0  0]]
# Mean absolute deviation (MAD) = 24.83318328857422
# Mean squared error (MSE) = 1610.4119873046875
# Mean absolute percentage error (MAPE) = 211.04300022125244
# Cohen kappa score = 0.0
# Epoch:30/30 AVG Training Loss:1395.031 AVG Val Loss:906.176
# Epoch:1/30 AVG MAPE:156.742
# Epoch:2/30 AVG MAPE:159.225
# Epoch:3/30 AVG MAPE:161.656
# Epoch:4/30 AVG MAPE:164.074
# Epoch:5/30 AVG MAPE:166.584
# Epoch:6/30 AVG MAPE:169.203
# Epoch:7/30 AVG MAPE:171.975
# Epoch:8/30 AVG MAPE:174.889
# Epoch:9/30 AVG MAPE:178.052
# Epoch:10/30 AVG MAPE:181.501
# Epoch:11/30 AVG MAPE:185.316
# Epoch:12/30 AVG MAPE:189.406
# Epoch:13/30 AVG MAPE:193.662
# Epoch:14/30 AVG MAPE:197.894
# Epoch:15/30 AVG MAPE:201.882
# Epoch:16/30 AVG MAPE:205.634
# Epoch:17/30 AVG MAPE:208.877
# Epoch:18/30 AVG MAPE:211.744
# Epoch:19/30 AVG MAPE:214.101
# Epoch:20/30 AVG MAPE:216.183
# Epoch:21/30 AVG MAPE:218.054
# Epoch:22/30 AVG MAPE:219.640
# Epoch:23/30 AVG MAPE:220.923
# Epoch:24/30 AVG MAPE:221.913
# Epoch:25/30 AVG MAPE:222.744
# Epoch:26/30 AVG MAPE:223.403
# Epoch:27/30 AVG MAPE:223.918
# Epoch:28/30 AVG MAPE:224.393
# Epoch:29/30 AVG MAPE:224.786
# Epoch:30/30 AVG MAPE:225.100
# Best epoch: 30 Best performance: 225.10018348693848
# Begin to evaluate the best model on test set
# Epoch:1/30 AVG Training Loss:2081.095
# Epoch:2/30 AVG Training Loss:2100.252
# Epoch:3/30 AVG Training Loss:2187.652
# Epoch:4/30 AVG Training Loss:2090.659
# Epoch:5/30 AVG Training Loss:2071.933
# Epoch:6/30 AVG Training Loss:2096.018
# Epoch:7/30 AVG Training Loss:2070.626
# Epoch:8/30 AVG Training Loss:2085.487
# Epoch:9/30 AVG Training Loss:2091.299
# Epoch:10/30 AVG Training Loss:2121.717
# Epoch:11/30 AVG Training Loss:2126.666
# Epoch:12/30 AVG Training Loss:2091.384
# Epoch:13/30 AVG Training Loss:2064.734
# Epoch:14/30 AVG Training Loss:2007.900
# Epoch:15/30 AVG Training Loss:2101.389
# Epoch:16/30 AVG Training Loss:nan
# Epoch:17/30 AVG Training Loss:nan
# Epoch:18/30 AVG Training Loss:nan
# Epoch:19/30 AVG Training Loss:nan
# Epoch:20/30 AVG Training Loss:nan
# Epoch:21/30 AVG Training Loss:nan
# Epoch:22/30 AVG Training Loss:nan
# Epoch:23/30 AVG Training Loss:nan
# Epoch:24/30 AVG Training Loss:nan
# Epoch:25/30 AVG Training Loss:nan
# Epoch:26/30 AVG Training Loss:nan
# Epoch:27/30 AVG Training Loss:nan
# Epoch:28/30 AVG Training Loss:nan
# Epoch:29/30 AVG Training Loss:nan
# Epoch:30/30 AVG Training Loss:nan
# error
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_32113/2611405837.py in <module>
#      61     test_loss, test_evaluation_scores = test_epoch(model, device, test_loader, criterion)
#      62     test_performance['test_loss'].append(test_loss)
# ---> 63     test_performance['test_mad'].append(test_evaluation_scores['mad'])
#      64     test_performance['test_mse'].append(test_evaluation_scores['mse'])
#      65     test_performance['test_mape'].append(test_evaluation_scores['mape'])
#
# KeyError: 'mad'

# %%
# Calculate average performance on 10-fold test set
print(test_performance)
test_mad_list = np.array(test_performance['test_mad'])
test_mse_list = np.array(test_performance['test_mse'])
test_mape_list = np.array(test_performance['test_mape'])
print('MAD: mean={:.3f}, std={:.3f}'.format(test_mad_list.mean(), test_mad_list.std()))
print('MSE: mean={:.3f}, std={:.3f}'.format(test_mse_list.mean(), test_mse_list.std()))
print('MAPE: mean={:.3f}, std={:.3f}'.format(test_mape_list.mean(), test_mape_list.std()))
# Out:
# {'test_loss': [2495.5590209960938, 2629.3311767578125, 1640.9576416015625], 'test_mad': [31.26084, 31.661581, 30.76814], 'test_mse': [2026.9153, 2069.3574, 1958.2748], 'test_mape': [179.81278896331787, 179.05292510986328, 177.4882435798645]}
# MAD: mean=31.230, std=0.365
# MSE: mean=2018.182, std=45.768
# MAPE: mean=178.785, std=0.968
