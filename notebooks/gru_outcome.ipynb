# %%
import numpy as np
import argparse
import os
import imp
import re
import pickle
import datetime
import random
import math
import copy

from sklearn.model_selection import KFold, StratifiedKFold, StratifiedShuffleSplit
import torch
from torch import nn
import torch.nn.utils.rnn as rnn_utils
from torch.utils import data
from torch.autograd import Variable
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader,TensorDataset,random_split,SubsetRandomSampler, ConcatDataset, Subset

from utils import metrics

# %%
def predict_all_visits_bce_loss(y_pred, y_true, x_lab_length):
    batch_size = len(y_true)
    loss = torch.nn.BCELoss()
    indices = torch.arange(batch_size, dtype=torch.int64)
    losses = 0
    for i in indices:
        visits_indices = torch.arange(x_lab_length[i], dtype=torch.int64)
        patient_losses = 0
        for v in visits_indices:
            patient_losses += loss(y_pred[i][v], y_true[i][v])
        losses += patient_losses/x_lab_length[i]
    return losses/batch_size

# %%
class Dataset(data.Dataset):
    def __init__(self, x, y, x_lab_length):
        self.x= x
        self.y = y
        self.x_lab_length = x_lab_length
        
    def __getitem__(self, index): # 返回的是tensor
        return self.x[index], self.y[index], self.x_lab_length[index]

    def __len__(self):
        return len(self.y)

# %%
data_path = '../dataset/tongji/processed_data/'
file_name = './ckpt/gru.pth'

batch_size = 64
num_epochs = 50
device = torch.device("cuda:0" if torch.cuda.is_available() == True else 'cpu')
# device = torch.device('cpu')

data_path = "../dataset/tongji/processed_data/"
x = pickle.load(open(data_path+"x.pkl", "rb"))
y = pickle.load(open(data_path+"y.pkl", "rb"))
x_lab_length = pickle.load(open(data_path+"visits_length.pkl", "rb"))
train_dataset = Dataset(x, y, x_lab_length)

# %%
class GRU(nn.Module):
    def __init__(self, input_demo_dim, input_lab_dim, max_visits, hidden_dim, output_dim, act_layer=nn.GELU, drop=0.):
        super(GRU, self).__init__()

        # hyperparameters
        self.input_demo_dim = input_demo_dim
        self.input_lab_dim = input_lab_dim
        self.max_visits = max_visits
        self.hidden_dim = hidden_dim
        self.output_dim = output_dim
        
        self.proj = nn.Linear(input_demo_dim+input_lab_dim, hidden_dim)
        self.bn = nn.BatchNorm1d(max_visits)
        self.gru = nn.GRU(input_size = hidden_dim, hidden_size = hidden_dim, num_layers = 1, batch_first = True)
        
        self.act = act_layer()
        self.fc = nn.Linear(hidden_dim, output_dim)
        self.drop = nn.Dropout(drop)

        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.proj(x)
        # x = self.act(x)
        # x = self.bn(x)
        x, _ = self.gru(x) # x: (batch_size,L,hidden_dim) h_n: (1, batch_size, hidden_dim)
        x = self.drop(x)
        x = self.fc(x)
        x = self.drop(x)
        x = self.sigmoid(x)
        return x

# %%
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED) # numpy
random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED) # cpu
torch.cuda.manual_seed(RANDOM_SEED) # gpu
torch.backends.cudnn.deterministic=True # cudnn
np.set_printoptions(threshold=np.inf, precision=2, suppress=True)


def train_epoch(model, device, dataloader, loss_fn, optimizer):
    train_loss = []
    model.train()
    for step, data in enumerate(dataloader):   
        batch_x, batch_y, batch_x_lab_length = data
        batch_x, batch_y, batch_x_lab_length = batch_x.float(), batch_y.float(), batch_x_lab_length.float()
        batch_y = batch_y[:,:,0] # 0: outcome, 1: los
        batch_y = batch_y.unsqueeze(-1)
        optimizer.zero_grad()
        output = model(batch_x)
        loss = loss_fn(output, batch_y, batch_x_lab_length)
        train_loss.append(loss.item())
        loss.backward()
        optimizer.step()
    return np.array(train_loss).mean()

def val_epoch(model, device, dataloader, loss_fn):
    """
    val / test
    """
    val_loss = []
    y_pred = []
    y_true = []
    model.eval()
    with torch.no_grad():
        for step, data in enumerate(dataloader):   
            batch_x, batch_y, batch_x_lab_length = data
            batch_x, batch_y, batch_x_lab_length = batch_x.float(), batch_y.float(), batch_x_lab_length.float()
            batch_y = batch_y[:,:,0] # 0: outcome, 1: los
            batch_y = batch_y.unsqueeze(-1)
            output = model(batch_x)
            loss = loss_fn(output, batch_y, batch_x_lab_length)
            val_loss.append(loss.item())
            for i in range(len(batch_y)):
                y_pred.extend(output[i][:batch_x_lab_length[i].long()].tolist())
                y_true.extend(batch_y[i][:batch_x_lab_length[i].long()].tolist())
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    y_pred = np.stack([1 - y_pred, y_pred], axis=1)
    evaluation_scores = metrics.print_metrics_binary(y_true, y_pred)
    return np.array(val_loss).mean(), evaluation_scores

# %%
model = GRU(input_lab_dim=25, input_demo_dim=2, max_visits=13, hidden_dim=32, output_dim=1, act_layer=nn.GELU, drop=0.).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
criterion = predict_all_visits_bce_loss
train_loader = DataLoader(train_dataset, batch_size=128)
train_loss = train_epoch(model, device, train_loader, criterion, optimizer)
val_loss = val_epoch(model, device, train_loader, criterion)
# Out:
# confusion matrix:
# [[1004   46]
#  [ 332  322]]
# accuracy = 0.7781690359115601
# precision class 0 = 0.7514970302581787
# precision class 1 = 0.875
# recall class 0 = 0.9561904668807983
# recall class 1 = 0.49235475063323975
# AUC of ROC = 0.8350924712392603
# AUC of PRC = 0.7870951405549289
# min(+P, Se) = 0.6931297709923664
# f1_score = 0.6301369949598974

# %%
all_history={}
test_performance={'test_loss': [],'test_accuracy':[], 'test_auroc':[], 'test_auprc':[]}
dataset = train_dataset
num_folds = 10
kfold_test = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=RANDOM_SEED)
skf = kfold_test.split(np.arange(len(dataset)), dataset.y[:, 0, 0])
for fold_test, (train_and_val_idx, test_idx) in enumerate(skf):
    print('====== Test Fold {} ======'.format(fold_test + 1))
    sss = StratifiedShuffleSplit(
        n_splits=1, test_size=1 / (num_folds - 1), random_state=RANDOM_SEED
    )

    test_sampler = SubsetRandomSampler(test_idx)
    test_loader = DataLoader(dataset, batch_size=batch_size, sampler=test_sampler)
    sub_dataset = Dataset(dataset.x[train_and_val_idx], dataset.y[train_and_val_idx], dataset.x_lab_length[train_and_val_idx])
    all_history['test_fold_{}'.format(fold_test+1)] = {}

    train_idx, val_idx = next(
        sss.split(np.arange(len(train_and_val_idx)), sub_dataset.y[:, 0, 0])
    )

    train_sampler = SubsetRandomSampler(train_idx)
    val_sampler = SubsetRandomSampler(val_idx)
    train_loader = DataLoader(dataset, batch_size=batch_size, sampler=train_sampler)
    val_loader = DataLoader(dataset, batch_size=batch_size, sampler=val_sampler)
    model = GRU(input_lab_dim=25, input_demo_dim=2, max_visits=13, hidden_dim=32, output_dim=1, act_layer=nn.GELU, drop=0.).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
    criterion = predict_all_visits_bce_loss
    history = {'train_loss': [], 'val_loss': [],'val_accuracy':[], 'val_auroc':[], 'val_auprc':[]}
    best_val_performance = 0.0
    for epoch in range(num_epochs):
        train_loss = train_epoch(model, device, train_loader, criterion, optimizer)
        val_loss, val_evaluation_scores=val_epoch(model, device, val_loader, criterion)
        # save performance history on validation set
        print("Epoch:{}/{} AVG Training Loss:{:.3f} AVG Val Loss:{:.3f}".format(epoch + 1, num_epochs, train_loss, val_loss))
        history['train_loss'].append(train_loss)
        history['val_loss'].append(val_loss)
        history['val_accuracy'].append(val_evaluation_scores['acc'])
        history['val_auroc'].append(val_evaluation_scores['auroc'])
        history['val_auprc'].append(val_evaluation_scores['auprc'])
        all_history['test_fold_{}'.format(fold_test+1)] = history

        # if auroc is better, than set the best auroc, save the model, and test it on the test set
        if val_evaluation_scores['auroc'] > best_val_performance:
            best_val_performance = val_evaluation_scores['auroc']
            torch.save(model.state_dict(), './checkpoints/gru_best_auroc.pth')
            
    print(
        f"Best performance on val set {fold_test+1}: \
        AUROC = {best_val_performance}"
    )
    model = GRU(input_lab_dim=25, input_demo_dim=2, max_visits=13, hidden_dim=32, output_dim=1, act_layer=nn.GELU, drop=0.).to(device)
    model.load_state_dict(torch.load('./checkpoints/gru_best_auroc.pth'))
    test_loss, test_evaluation_scores = val_epoch(model, device, test_loader, criterion)
    test_performance['test_loss'].append(test_loss)
    test_performance['test_accuracy'].append(test_evaluation_scores['acc'])
    test_performance['test_auroc'].append(test_evaluation_scores['auroc'])
    test_performance['test_auprc'].append(test_evaluation_scores['auprc'])
    print(f"Performance on test set {fold_test+1}: Accuracy = {test_evaluation_scores['acc']}, AUROC = {test_evaluation_scores['auroc']}, AUPRC = {test_evaluation_scores['auprc']}")
# Out:
# ====== Test Fold 1 ======
# confusion matrix:
# [[102   5]
#  [ 29  30]]
# accuracy = 0.7951807379722595
# precision class 0 = 0.7786259651184082
# precision class 1 = 0.8571428656578064
# recall class 0 = 0.9532710313796997
# recall class 1 = 0.508474588394165
# AUC of ROC = 0.8824647552669095
# AUC of PRC = 0.8549289341398226
# min(+P, Se) = 0.7796610169491526
# f1_score = 0.6382978563936883
# Epoch:1/50 AVG Training Loss:0.686 AVG Val Loss:0.653
# confusion matrix:
# [[107   0]
#  [ 21  38]]
# accuracy = 0.8734939694404602
# precision class 0 = 0.8359375
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.6440678238868713
# AUC of ROC = 0.9600823697132901
# AUC of PRC = 0.951056853035557
# min(+P, Se) = 0.864406779661017
# f1_score = 0.7835052032275093
# Epoch:2/50 AVG Training Loss:0.630 AVG Val Loss:0.597
# confusion matrix:
# [[107   0]
#  [ 18  41]]
# accuracy = 0.891566276550293
# precision class 0 = 0.8560000061988831
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.694915235042572
# AUC of ROC = 0.9681609377475051
# AUC of PRC = 0.964073481659464
# min(+P, Se) = 0.9152542372881356
# f1_score = 0.8199999577999125
# Epoch:3/50 AVG Training Loss:0.577 AVG Val Loss:0.541
# confusion matrix:
# [[107   0]
#  [ 16  43]]
# accuracy = 0.9036144614219666
# precision class 0 = 0.869918704032898
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.7288135886192322
# AUC of ROC = 0.969586567400602
# AUC of PRC = 0.9669250050287732
# min(+P, Se) = 0.9152542372881356
# f1_score = 0.8431372454376328
# Epoch:4/50 AVG Training Loss:0.525 AVG Val Loss:0.486
# confusion matrix:
# [[107   0]
#  [ 16  43]]
# accuracy = 0.9036144614219666
# precision class 0 = 0.869918704032898
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.7288135886192322
# AUC of ROC = 0.9705369871693331
# AUC of PRC = 0.9677926701013744
# min(+P, Se) = 0.9152542372881356
# f1_score = 0.8431372454376328
# Epoch:5/50 AVG Training Loss:0.476 AVG Val Loss:0.434
# confusion matrix:
# [[107   0]
#  [ 15  44]]
# accuracy = 0.9096385836601257
# precision class 0 = 0.8770492076873779
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.7457627058029175
# AUC of ROC = 0.9713290036432758
# AUC of PRC = 0.9682257902259168
# min(+P, Se) = 0.9152542372881356
# f1_score = 0.8543689280610719
# Epoch:6/50 AVG Training Loss:0.441 AVG Val Loss:0.388
# confusion matrix:
# [[107   0]
#  [ 15  44]]
# accuracy = 0.9096385836601257
# precision class 0 = 0.8770492076873779
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.7457627058029175
# AUC of ROC = 0.9722794234120069
# AUC of PRC = 0.9687493508580172
# min(+P, Se) = 0.9152542372881356
# f1_score = 0.8543689280610719
# Epoch:7/50 AVG Training Loss:0.393 AVG Val Loss:0.351
# confusion matrix:
# [[107   0]
#  [ 11  48]]
# accuracy = 0.9337349534034729
# precision class 0 = 0.9067796468734741
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8135592937469482
# AUC of ROC = 0.972913036591161
# AUC of PRC = 0.9691285177131415
# min(+P, Se) = 0.9152542372881356
# f1_score = 0.8971962444812867
# Epoch:8/50 AVG Training Loss:0.367 AVG Val Loss:0.320
# confusion matrix:
# [[107   0]
#  [  9  50]]
# accuracy = 0.9457831382751465
# precision class 0 = 0.9224137663841248
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8474576473236084
# AUC of ROC = 0.9743386662442578
# AUC of PRC = 0.9701129234041184
# min(+P, Se) = 0.9152542372881356
# f1_score = 0.9174312045002071
# Epoch:9/50 AVG Training Loss:0.338 AVG Val Loss:0.294
# confusion matrix:
# [[107   0]
#  [  9  50]]
# accuracy = 0.9457831382751465
# precision class 0 = 0.9224137663841248
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8474576473236084
# AUC of ROC = 0.9759226991921433
# AUC of PRC = 0.9712013870460012
# min(+P, Se) = 0.9152542372881356
# f1_score = 0.9174312045002071
# Epoch:10/50 AVG Training Loss:0.305 AVG Val Loss:0.273
# confusion matrix:
# [[107   0]
#  [  9  50]]
# accuracy = 0.9457831382751465
# precision class 0 = 0.9224137663841248
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8474576473236084
# AUC of ROC = 0.9773483288452399
# AUC of PRC = 0.9722868183041087
# min(+P, Se) = 0.9152542372881356
# f1_score = 0.9174312045002071
# Epoch:11/50 AVG Training Loss:0.282 AVG Val Loss:0.254
# confusion matrix:
# [[107   0]
#  [  8  51]]
# accuracy = 0.9518072009086609
# precision class 0 = 0.9304347634315491
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8644067645072937
# AUC of ROC = 0.9782987486139711
# AUC of PRC = 0.9732660834470439
# min(+P, Se) = 0.9152542372881356
# f1_score = 0.9272726889090114
# Epoch:12/50 AVG Training Loss:0.270 AVG Val Loss:0.238
# confusion matrix:
# [[107   0]
#  [  8  51]]
# accuracy = 0.9518072009086609
# precision class 0 = 0.9304347634315491
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8644067645072937
# AUC of ROC = 0.9803579914462222
# AUC of PRC = 0.9749693172637295
# min(+P, Se) = 0.9152542372881356
# f1_score = 0.9272726889090114
# Epoch:13/50 AVG Training Loss:0.238 AVG Val Loss:0.223
# confusion matrix:
# [[107   0]
#  [  8  51]]
# accuracy = 0.9518072009086609
# precision class 0 = 0.9304347634315491
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8644067645072937
# AUC of ROC = 0.9813084112149533
# AUC of PRC = 0.9759050839207686
# min(+P, Se) = 0.9152542372881356
# f1_score = 0.9272726889090114
# Epoch:14/50 AVG Training Loss:0.230 AVG Val Loss:0.211
# confusion matrix:
# [[107   0]
#  [  8  51]]
# accuracy = 0.9518072009086609
# precision class 0 = 0.9304347634315491
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8644067645072937
# AUC of ROC = 0.9830508474576272
# AUC of PRC = 0.9779175134432291
# min(+P, Se) = 0.9152542372881356
# f1_score = 0.9272726889090114
# Epoch:15/50 AVG Training Loss:0.210 AVG Val Loss:0.200
# confusion matrix:
# [[107   0]
#  [  8  51]]
# accuracy = 0.9518072009086609
# precision class 0 = 0.9304347634315491
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8644067645072937
# AUC of ROC = 0.9836844606367814
# AUC of PRC = 0.9785113957385427
# min(+P, Se) = 0.9166666666666666
# f1_score = 0.9272726889090114
# Epoch:16/50 AVG Training Loss:0.201 AVG Val Loss:0.191
# confusion matrix:
# [[107   0]
#  [  8  51]]
# accuracy = 0.9518072009086609
# precision class 0 = 0.9304347634315491
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8644067645072937
# AUC of ROC = 0.9844764771107237
# AUC of PRC = 0.9792548317364562
# min(+P, Se) = 0.9166666666666666
# f1_score = 0.9272726889090114
# Epoch:17/50 AVG Training Loss:0.197 AVG Val Loss:0.183
# confusion matrix:
# [[107   0]
#  [  8  51]]
# accuracy = 0.9518072009086609
# precision class 0 = 0.9304347634315491
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8644067645072937
# AUC of ROC = 0.9857437034690322
# AUC of PRC = 0.9806105044283759
# min(+P, Se) = 0.9166666666666666
# f1_score = 0.9272726889090114
# Epoch:18/50 AVG Training Loss:0.186 AVG Val Loss:0.176
# confusion matrix:
# [[107   0]
#  [  8  51]]
# accuracy = 0.9518072009086609
# precision class 0 = 0.9304347634315491
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8644067645072937
# AUC of ROC = 0.9862189133533978
# AUC of PRC = 0.9811800025538562
# min(+P, Se) = 0.9166666666666666
# f1_score = 0.9272726889090114
# Epoch:19/50 AVG Training Loss:0.177 AVG Val Loss:0.172
# confusion matrix:
# [[107   0]
#  [  8  51]]
# accuracy = 0.9518072009086609
# precision class 0 = 0.9304347634315491
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8644067645072937
# AUC of ROC = 0.9863773166481864
# AUC of PRC = 0.9815099134804086
# min(+P, Se) = 0.9322033898305084
# f1_score = 0.9272726889090114
# Epoch:20/50 AVG Training Loss:0.170 AVG Val Loss:0.170
# confusion matrix:
# [[107   0]
#  [  8  51]]
# accuracy = 0.9518072009086609
# precision class 0 = 0.9304347634315491
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8644067645072937
# AUC of ROC = 0.9857437034690322
# AUC of PRC = 0.9808493233263842
# min(+P, Se) = 0.9322033898305084
# f1_score = 0.9272726889090114
# Epoch:21/50 AVG Training Loss:0.171 AVG Val Loss:0.169
# confusion matrix:
# [[107   0]
#  [  8  51]]
# accuracy = 0.9518072009086609
# precision class 0 = 0.9304347634315491
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8644067645072937
# AUC of ROC = 0.9862189133533978
# AUC of PRC = 0.9813711943998857
# min(+P, Se) = 0.9333333333333333
# f1_score = 0.9272726889090114
# Epoch:22/50 AVG Training Loss:0.164 AVG Val Loss:0.168
# confusion matrix:
# [[107   0]
#  [  8  51]]
# accuracy = 0.9518072009086609
# precision class 0 = 0.9304347634315491
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8644067645072937
# AUC of ROC = 0.987169333122129
# AUC of PRC = 0.9822515291086884
# min(+P, Se) = 0.9333333333333333
# f1_score = 0.9272726889090114
# Epoch:23/50 AVG Training Loss:0.157 AVG Val Loss:0.165
# confusion matrix:
# [[107   0]
#  [  8  51]]
# accuracy = 0.9518072009086609
# precision class 0 = 0.9304347634315491
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8644067645072937
# AUC of ROC = 0.9876445430064945
# AUC of PRC = 0.982859359402039
# min(+P, Se) = 0.9322033898305084
# f1_score = 0.9272726889090114
# Epoch:24/50 AVG Training Loss:0.153 AVG Val Loss:0.163
# confusion matrix:
# [[107   0]
#  [  8  51]]
# accuracy = 0.9518072009086609
# precision class 0 = 0.9304347634315491
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8644067645072937
# AUC of ROC = 0.9881197528908602
# AUC of PRC = 0.9832675588317357
# min(+P, Se) = 0.9322033898305084
# f1_score = 0.9272726889090114
# Epoch:25/50 AVG Training Loss:0.152 AVG Val Loss:0.160
# confusion matrix:
# [[107   0]
#  [  8  51]]
# accuracy = 0.9518072009086609
# precision class 0 = 0.9304347634315491
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8644067645072937
# AUC of ROC = 0.9882781561856486
# AUC of PRC = 0.9833647538984578
# min(+P, Se) = 0.9322033898305084
# f1_score = 0.9272726889090114
# Epoch:26/50 AVG Training Loss:0.162 AVG Val Loss:0.158
# confusion matrix:
# [[107   0]
#  [  8  51]]
# accuracy = 0.9518072009086609
# precision class 0 = 0.9304347634315491
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8644067645072937
# AUC of ROC = 0.9889117693648027
# AUC of PRC = 0.9841477499254598
# min(+P, Se) = 0.9322033898305084
# f1_score = 0.9272726889090114
# Epoch:27/50 AVG Training Loss:0.144 AVG Val Loss:0.155
# confusion matrix:
# [[107   0]
#  [  8  51]]
# accuracy = 0.9518072009086609
# precision class 0 = 0.9304347634315491
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8644067645072937
# AUC of ROC = 0.9887533660700142
# AUC of PRC = 0.9839107178062516
# min(+P, Se) = 0.9322033898305084
# f1_score = 0.9272726889090114
# Epoch:28/50 AVG Training Loss:0.140 AVG Val Loss:0.154
# confusion matrix:
# [[107   0]
#  [  8  51]]
# accuracy = 0.9518072009086609
# precision class 0 = 0.9304347634315491
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8644067645072937
# AUC of ROC = 0.989862189133534
# AUC of PRC = 0.9849559627554336
# min(+P, Se) = 0.9322033898305084
# f1_score = 0.9272726889090114
# Epoch:29/50 AVG Training Loss:0.146 AVG Val Loss:0.153
# confusion matrix:
# [[107   0]
#  [  8  51]]
# accuracy = 0.9518072009086609
# precision class 0 = 0.9304347634315491
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8644067645072937
# AUC of ROC = 0.9906542056074765
# AUC of PRC = 0.9859531682488185
# min(+P, Se) = 0.9322033898305084
# f1_score = 0.9272726889090114
# Epoch:30/50 AVG Training Loss:0.137 AVG Val Loss:0.150
# confusion matrix:
# [[107   0]
#  [  8  51]]
# accuracy = 0.9518072009086609
# precision class 0 = 0.9304347634315491
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8644067645072937
# AUC of ROC = 0.9908126089022651
# AUC of PRC = 0.9861120493626983
# min(+P, Se) = 0.9322033898305084
# f1_score = 0.9272726889090114
# Epoch:31/50 AVG Training Loss:0.144 AVG Val Loss:0.148
# confusion matrix:
# [[107   0]
#  [  8  51]]
# accuracy = 0.9518072009086609
# precision class 0 = 0.9304347634315491
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8644067645072937
# AUC of ROC = 0.9912878187866307
# AUC of PRC = 0.9866762986944306
# min(+P, Se) = 0.9322033898305084
# f1_score = 0.9272726889090114
# Epoch:32/50 AVG Training Loss:0.144 AVG Val Loss:0.148
# confusion matrix:
# [[107   0]
#  [  7  52]]
# accuracy = 0.9578313231468201
# precision class 0 = 0.9385964870452881
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8813559412956238
# AUC of ROC = 0.9920798352605733
# AUC of PRC = 0.9875533878993416
# min(+P, Se) = 0.9322033898305084
# f1_score = 0.9369369123907185
# Epoch:33/50 AVG Training Loss:0.137 AVG Val Loss:0.147
# confusion matrix:
# [[107   0]
#  [  7  52]]
# accuracy = 0.9578313231468201
# precision class 0 = 0.9385964870452881
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8813559412956238
# AUC of ROC = 0.992555045144939
# AUC of PRC = 0.988125259953212
# min(+P, Se) = 0.9322033898305084
# f1_score = 0.9369369123907185
# Epoch:34/50 AVG Training Loss:0.132 AVG Val Loss:0.146
# confusion matrix:
# [[107   0]
#  [  7  52]]
# accuracy = 0.9578313231468201
# precision class 0 = 0.9385964870452881
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8813559412956238
# AUC of ROC = 0.9928718517345161
# AUC of PRC = 0.9885034286564531
# min(+P, Se) = 0.9322033898305084
# f1_score = 0.9369369123907185
# Epoch:35/50 AVG Training Loss:0.126 AVG Val Loss:0.144
# confusion matrix:
# [[107   0]
#  [  7  52]]
# accuracy = 0.9578313231468201
# precision class 0 = 0.9385964870452881
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8813559412956238
# AUC of ROC = 0.9928718517345161
# AUC of PRC = 0.9885034286564531
# min(+P, Se) = 0.9322033898305084
# f1_score = 0.9369369123907185
# Epoch:36/50 AVG Training Loss:0.125 AVG Val Loss:0.143
# confusion matrix:
# [[107   0]
#  [  7  52]]
# accuracy = 0.9578313231468201
# precision class 0 = 0.9385964870452881
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8813559412956238
# AUC of ROC = 0.9933470616188816
# AUC of PRC = 0.9892107537845247
# min(+P, Se) = 0.9322033898305084
# f1_score = 0.9369369123907185
# Epoch:37/50 AVG Training Loss:0.131 AVG Val Loss:0.140
# confusion matrix:
# [[107   0]
#  [  7  52]]
# accuracy = 0.9578313231468201
# precision class 0 = 0.9385964870452881
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8813559412956238
# AUC of ROC = 0.9935054649136702
# AUC of PRC = 0.9894190316424623
# min(+P, Se) = 0.9322033898305084
# f1_score = 0.9369369123907185
# Epoch:38/50 AVG Training Loss:0.124 AVG Val Loss:0.137
# confusion matrix:
# [[107   0]
#  [  7  52]]
# accuracy = 0.9578313231468201
# precision class 0 = 0.9385964870452881
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8813559412956238
# AUC of ROC = 0.9936638682084586
# AUC of PRC = 0.9896388935749475
# min(+P, Se) = 0.9322033898305084
# f1_score = 0.9369369123907185
# Epoch:39/50 AVG Training Loss:0.121 AVG Val Loss:0.136
# confusion matrix:
# [[107   0]
#  [  7  52]]
# accuracy = 0.9578313231468201
# precision class 0 = 0.9385964870452881
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8813559412956238
# AUC of ROC = 0.9933470616188816
# AUC of PRC = 0.9891192215968896
# min(+P, Se) = 0.9322033898305084
# f1_score = 0.9369369123907185
# Epoch:40/50 AVG Training Loss:0.117 AVG Val Loss:0.137
# confusion matrix:
# [[107   0]
#  [  7  52]]
# accuracy = 0.9578313231468201
# precision class 0 = 0.9385964870452881
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8813559412956238
# AUC of ROC = 0.9936638682084588
# AUC of PRC = 0.9895761156485829
# min(+P, Se) = 0.9322033898305084
# f1_score = 0.9369369123907185
# Epoch:41/50 AVG Training Loss:0.116 AVG Val Loss:0.137
# confusion matrix:
# [[107   0]
#  [  7  52]]
# accuracy = 0.9578313231468201
# precision class 0 = 0.9385964870452881
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8813559412956238
# AUC of ROC = 0.9938222715032472
# AUC of PRC = 0.9898027957481443
# min(+P, Se) = 0.9322033898305084
# f1_score = 0.9369369123907185
# Epoch:42/50 AVG Training Loss:0.126 AVG Val Loss:0.137
# confusion matrix:
# [[107   0]
#  [  7  52]]
# accuracy = 0.9578313231468201
# precision class 0 = 0.9385964870452881
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8813559412956238
# AUC of ROC = 0.9938222715032472
# AUC of PRC = 0.9898027957481443
# min(+P, Se) = 0.9322033898305084
# f1_score = 0.9369369123907185
# Epoch:43/50 AVG Training Loss:0.125 AVG Val Loss:0.140
# confusion matrix:
# [[107   0]
#  [  7  52]]
# accuracy = 0.9578313231468201
# precision class 0 = 0.9385964870452881
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8813559412956238
# AUC of ROC = 0.9941390780928243
# AUC of PRC = 0.9902436729564804
# min(+P, Se) = 0.9322033898305084
# f1_score = 0.9369369123907185
# Epoch:44/50 AVG Training Loss:0.123 AVG Val Loss:0.138
# confusion matrix:
# [[107   0]
#  [  7  52]]
# accuracy = 0.9578313231468201
# precision class 0 = 0.9385964870452881
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8813559412956238
# AUC of ROC = 0.9942974813876129
# AUC of PRC = 0.9904884143770861
# min(+P, Se) = 0.9322033898305084
# f1_score = 0.9369369123907185
# Epoch:45/50 AVG Training Loss:0.121 AVG Val Loss:0.134
# confusion matrix:
# [[107   0]
#  [  7  52]]
# accuracy = 0.9578313231468201
# precision class 0 = 0.9385964870452881
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8813559412956238
# AUC of ROC = 0.9942974813876129
# AUC of PRC = 0.9904884143770861
# min(+P, Se) = 0.9322033898305084
# f1_score = 0.9369369123907185
# Epoch:46/50 AVG Training Loss:0.111 AVG Val Loss:0.135
# confusion matrix:
# [[107   0]
#  [  7  52]]
# accuracy = 0.9578313231468201
# precision class 0 = 0.9385964870452881
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8813559412956238
# AUC of ROC = 0.9944558846824014
# AUC of PRC = 0.9907222348174743
# min(+P, Se) = 0.9322033898305084
# f1_score = 0.9369369123907185
# Epoch:47/50 AVG Training Loss:0.127 AVG Val Loss:0.136
# confusion matrix:
# [[107   0]
#  [  7  52]]
# accuracy = 0.9578313231468201
# precision class 0 = 0.9385964870452881
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8813559412956238
# AUC of ROC = 0.9944558846824014
# AUC of PRC = 0.9907222348174743
# min(+P, Se) = 0.9322033898305084
# f1_score = 0.9369369123907185
# Epoch:48/50 AVG Training Loss:0.119 AVG Val Loss:0.137
# confusion matrix:
# [[107   0]
#  [  7  52]]
# accuracy = 0.9578313231468201
# precision class 0 = 0.9385964870452881
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8813559412956238
# AUC of ROC = 0.9944558846824014
# AUC of PRC = 0.9906685740101089
# min(+P, Se) = 0.9322033898305084
# f1_score = 0.9369369123907185
# Epoch:49/50 AVG Training Loss:0.107 AVG Val Loss:0.137
# confusion matrix:
# [[107   0]
#  [  7  52]]
# accuracy = 0.9578313231468201
# precision class 0 = 0.9385964870452881
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8813559412956238
# AUC of ROC = 0.9944558846824014
# AUC of PRC = 0.9906685740101089
# min(+P, Se) = 0.9322033898305084
# f1_score = 0.9369369123907185
# Epoch:50/50 AVG Training Loss:0.103 AVG Val Loss:0.137
# Best performance on val set 1:         AUROC = 0.9944558846824014
# confusion matrix:
# [[107   0]
#  [  9  57]]
# accuracy = 0.9479768872261047
# precision class 0 = 0.9224137663841248
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8636363744735718
# AUC of ROC = 0.9883885584820165
# AUC of PRC = 0.9846828218253756
# min(+P, Se) = 0.9242424242424242
# f1_score = 0.9268292745332644
# Performance on test set 1: Accuracy = 0.9479768872261047, AUROC = 0.9883885584820165, AUPRC = 0.9846828218253756
# ====== Test Fold 2 ======
# confusion matrix:
# [[  0 110]
#  [  0  61]]
# accuracy = 0.35672515630722046
# precision class 0 = nan
# precision class 1 = 0.35672515630722046
# recall class 0 = 0.0
# recall class 1 = 1.0
# AUC of ROC = 0.7120715350223547
# AUC of PRC = 0.5811063394932683
# min(+P, Se) = 0.5573770491803278
# f1_score = 0.525862056846143
# Epoch:1/50 AVG Training Loss:0.729 AVG Val Loss:0.708
# confusion matrix:
# [[38 72]
#  [ 0 61]]
# accuracy = 0.5789473652839661
# precision class 0 = 1.0
# precision class 1 = 0.45864662528038025
# recall class 0 = 0.34545454382896423
# recall class 1 = 1.0
# AUC of ROC = 0.9129657228017883
# AUC of PRC = 0.8821325823976361
# min(+P, Se) = 0.7704918032786885
# f1_score = 0.6288659747474975
# Epoch:2/50 AVG Training Loss:0.684 AVG Val Loss:0.663
# /home/zhuyh/projects/covid-emr/notebooks/utils/metrics.py:22: RuntimeWarning: invalid value encountered in float_scalars
#   prec0 = cf[0][0] / (cf[0][0] + cf[1][0])
# confusion matrix:
# [[84 26]
#  [ 5 56]]
# accuracy = 0.8187134265899658
# precision class 0 = 0.9438202381134033
# precision class 1 = 0.6829268336296082
# recall class 0 = 0.7636363506317139
# recall class 1 = 0.9180327653884888
# AUC of ROC = 0.94575260804769
# AUC of PRC = 0.9233012766035514
# min(+P, Se) = 0.7868852459016393
# f1_score = 0.7832168074212427
# Epoch:3/50 AVG Training Loss:0.634 AVG Val Loss:0.614
# confusion matrix:
# [[99 11]
#  [11 50]]
# accuracy = 0.871345043182373
# precision class 0 = 0.8999999761581421
# precision class 1 = 0.8196721076965332
# recall class 0 = 0.8999999761581421
# recall class 1 = 0.8196721076965332
# AUC of ROC = 0.9543964232488823
# AUC of PRC = 0.9348388417810125
# min(+P, Se) = 0.819672131147541
# f1_score = 0.8196721076965332
# Epoch:4/50 AVG Training Loss:0.582 AVG Val Loss:0.560
# confusion matrix:
# [[104   6]
#  [ 13  48]]
# accuracy = 0.8888888955116272
# precision class 0 = 0.8888888955116272
# precision class 1 = 0.8888888955116272
# recall class 0 = 0.9454545378684998
# recall class 1 = 0.7868852615356445
# AUC of ROC = 0.9575260804769001
# AUC of PRC = 0.9395256175129669
# min(+P, Se) = 0.828125
# f1_score = 0.8347826501056703
# Epoch:5/50 AVG Training Loss:0.522 AVG Val Loss:0.504
# confusion matrix:
# [[107   3]
#  [ 14  47]]
# accuracy = 0.9005848169326782
# precision class 0 = 0.8842975497245789
# precision class 1 = 0.9399999976158142
# recall class 0 = 0.9727272987365723
# recall class 1 = 0.7704917788505554
# AUC of ROC = 0.9588673621460506
# AUC of PRC = 0.9405621669357874
# min(+P, Se) = 0.8524590163934426
# f1_score = 0.846846831124495
# Epoch:6/50 AVG Training Loss:0.458 AVG Val Loss:0.453
# confusion matrix:
# [[107   3]
#  [ 14  47]]
# accuracy = 0.9005848169326782
# precision class 0 = 0.8842975497245789
# precision class 1 = 0.9399999976158142
# recall class 0 = 0.9727272987365723
# recall class 1 = 0.7704917788505554
# AUC of ROC = 0.9597615499254843
# AUC of PRC = 0.9417396613620532
# min(+P, Se) = 0.8524590163934426
# f1_score = 0.846846831124495
# Epoch:7/50 AVG Training Loss:0.416 AVG Val Loss:0.411
# confusion matrix:
# [[107   3]
#  [ 14  47]]
# accuracy = 0.9005848169326782
# precision class 0 = 0.8842975497245789
# precision class 1 = 0.9399999976158142
# recall class 0 = 0.9727272987365723
# recall class 1 = 0.7704917788505554
# AUC of ROC = 0.9618479880774963
# AUC of PRC = 0.944651643183042
# min(+P, Se) = 0.8709677419354839
# f1_score = 0.846846831124495
# Epoch:8/50 AVG Training Loss:0.375 AVG Val Loss:0.380
# confusion matrix:
# [[107   3]
#  [ 14  47]]
# accuracy = 0.9005848169326782
# precision class 0 = 0.8842975497245789
# precision class 1 = 0.9399999976158142
# recall class 0 = 0.9727272987365723
# recall class 1 = 0.7704917788505554
# AUC of ROC = 0.9634873323397914
# AUC of PRC = 0.9482847426260701
# min(+P, Se) = 0.873015873015873
# f1_score = 0.846846831124495
# Epoch:9/50 AVG Training Loss:0.341 AVG Val Loss:0.357
# confusion matrix:
# [[107   3]
#  [ 14  47]]
# accuracy = 0.9005848169326782
# precision class 0 = 0.8842975497245789
# precision class 1 = 0.9399999976158142
# recall class 0 = 0.9727272987365723
# recall class 1 = 0.7704917788505554
# AUC of ROC = 0.9658718330849478
# AUC of PRC = 0.9522603121193172
# min(+P, Se) = 0.873015873015873
# f1_score = 0.846846831124495
# Epoch:10/50 AVG Training Loss:0.324 AVG Val Loss:0.338
# confusion matrix:
# [[107   3]
#  [ 12  49]]
# accuracy = 0.9122806787490845
# precision class 0 = 0.8991596698760986
# precision class 1 = 0.942307710647583
# recall class 0 = 0.9727272987365723
# recall class 1 = 0.8032786846160889
# AUC of ROC = 0.9672131147540983
# AUC of PRC = 0.9547442872038667
# min(+P, Se) = 0.873015873015873
# f1_score = 0.867256642657613
# Epoch:11/50 AVG Training Loss:0.284 AVG Val Loss:0.320
# confusion matrix:
# [[107   3]
#  [  9  52]]
# accuracy = 0.9298245906829834
# precision class 0 = 0.9224137663841248
# precision class 1 = 0.9454545378684998
# recall class 0 = 0.9727272987365723
# recall class 1 = 0.8524590134620667
# AUC of ROC = 0.9688524590163934
# AUC of PRC = 0.9569470305982027
# min(+P, Se) = 0.873015873015873
# f1_score = 0.8965517191059099
# Epoch:12/50 AVG Training Loss:0.264 AVG Val Loss:0.303
# confusion matrix:
# [[107   3]
#  [  9  52]]
# accuracy = 0.9298245906829834
# precision class 0 = 0.9224137663841248
# precision class 1 = 0.9454545378684998
# recall class 0 = 0.9727272987365723
# recall class 1 = 0.8524590134620667
# AUC of ROC = 0.9713859910581222
# AUC of PRC = 0.9612076777074124
# min(+P, Se) = 0.873015873015873
# f1_score = 0.8965517191059099
# Epoch:13/50 AVG Training Loss:0.244 AVG Val Loss:0.286
# confusion matrix:
# [[108   2]
#  [  9  52]]
# accuracy = 0.9356725215911865
# precision class 0 = 0.9230769276618958
# precision class 1 = 0.9629629850387573
# recall class 0 = 0.9818181991577148
# recall class 1 = 0.8524590134620667
# AUC of ROC = 0.9743666169895677
# AUC of PRC = 0.9654083341308217
# min(+P, Se) = 0.873015873015873
# f1_score = 0.9043478044805553
# Epoch:14/50 AVG Training Loss:0.226 AVG Val Loss:0.270
# confusion matrix:
# [[109   1]
#  [  9  52]]
# accuracy = 0.9415204524993896
# precision class 0 = 0.9237288236618042
# precision class 1 = 0.9811320900917053
# recall class 0 = 0.9909090995788574
# recall class 1 = 0.8524590134620667
# AUC of ROC = 0.9770491803278688
# AUC of PRC = 0.9685147793509364
# min(+P, Se) = 0.8852459016393442
# f1_score = 0.9122807063958064
# Epoch:15/50 AVG Training Loss:0.226 AVG Val Loss:0.255
# confusion matrix:
# [[110   0]
#  [  9  52]]
# accuracy = 0.9473684430122375
# precision class 0 = 0.924369752407074
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8524590134620667
# AUC of ROC = 0.9780923994038748
# AUC of PRC = 0.9696322308988836
# min(+P, Se) = 0.8870967741935484
# f1_score = 0.9203540102056996
# Epoch:16/50 AVG Training Loss:0.206 AVG Val Loss:0.243
# confusion matrix:
# [[110   0]
#  [  9  52]]
# accuracy = 0.9473684430122375
# precision class 0 = 0.924369752407074
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8524590134620667
# AUC of ROC = 0.9794336810730253
# AUC of PRC = 0.9713917439178159
# min(+P, Se) = 0.8870967741935484
# f1_score = 0.9203540102056996
# Epoch:17/50 AVG Training Loss:0.199 AVG Val Loss:0.232
# confusion matrix:
# [[110   0]
#  [  9  52]]
# accuracy = 0.9473684430122375
# precision class 0 = 0.924369752407074
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8524590134620667
# AUC of ROC = 0.9794336810730253
# AUC of PRC = 0.9713917439178159
# min(+P, Se) = 0.8870967741935484
# f1_score = 0.9203540102056996
# Epoch:18/50 AVG Training Loss:0.181 AVG Val Loss:0.222
# confusion matrix:
# [[110   0]
#  [  9  52]]
# accuracy = 0.9473684430122375
# precision class 0 = 0.924369752407074
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8524590134620667
# AUC of ROC = 0.980327868852459
# AUC of PRC = 0.9727181173094019
# min(+P, Se) = 0.9016393442622951
# f1_score = 0.9203540102056996
# Epoch:19/50 AVG Training Loss:0.177 AVG Val Loss:0.213
# confusion matrix:
# [[110   0]
#  [  9  52]]
# accuracy = 0.9473684430122375
# precision class 0 = 0.924369752407074
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8524590134620667
# AUC of ROC = 0.9810730253353204
# AUC of PRC = 0.9739973336912566
# min(+P, Se) = 0.9016393442622951
# f1_score = 0.9203540102056996
# Epoch:20/50 AVG Training Loss:0.169 AVG Val Loss:0.207
# confusion matrix:
# [[110   0]
#  [  9  52]]
# accuracy = 0.9473684430122375
# precision class 0 = 0.924369752407074
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8524590134620667
# AUC of ROC = 0.981371087928465
# AUC of PRC = 0.9744230919159065
# min(+P, Se) = 0.9032258064516129
# f1_score = 0.9203540102056996
# Epoch:21/50 AVG Training Loss:0.169 AVG Val Loss:0.201
# confusion matrix:
# [[110   0]
#  [  8  53]]
# accuracy = 0.9532163739204407
# precision class 0 = 0.9322034120559692
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.868852436542511
# AUC of ROC = 0.981371087928465
# AUC of PRC = 0.9744230919159065
# min(+P, Se) = 0.9032258064516129
# f1_score = 0.9298245781896745
# Epoch:22/50 AVG Training Loss:0.158 AVG Val Loss:0.198
# confusion matrix:
# [[110   0]
#  [  8  53]]
# accuracy = 0.9532163739204407
# precision class 0 = 0.9322034120559692
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.868852436542511
# AUC of ROC = 0.981371087928465
# AUC of PRC = 0.9742953070010913
# min(+P, Se) = 0.9032258064516129
# f1_score = 0.9298245781896745
# Epoch:23/50 AVG Training Loss:0.152 AVG Val Loss:0.196
# confusion matrix:
# [[110   0]
#  [  8  53]]
# accuracy = 0.9532163739204407
# precision class 0 = 0.9322034120559692
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.868852436542511
# AUC of ROC = 0.9815201192250371
# AUC of PRC = 0.9745564489419891
# min(+P, Se) = 0.9032258064516129
# f1_score = 0.9298245781896745
# Epoch:24/50 AVG Training Loss:0.146 AVG Val Loss:0.193
# confusion matrix:
# [[110   0]
#  [  8  53]]
# accuracy = 0.9532163739204407
# precision class 0 = 0.9322034120559692
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.868852436542511
# AUC of ROC = 0.9821162444113263
# AUC of PRC = 0.9755113125898676
# min(+P, Se) = 0.9032258064516129
# f1_score = 0.9298245781896745
# Epoch:25/50 AVG Training Loss:0.156 AVG Val Loss:0.191
# confusion matrix:
# [[110   0]
#  [  8  53]]
# accuracy = 0.9532163739204407
# precision class 0 = 0.9322034120559692
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.868852436542511
# AUC of ROC = 0.9828614008941877
# AUC of PRC = 0.9762875227154193
# min(+P, Se) = 0.9032258064516129
# f1_score = 0.9298245781896745
# Epoch:26/50 AVG Training Loss:0.142 AVG Val Loss:0.187
# confusion matrix:
# [[110   0]
#  [  8  53]]
# accuracy = 0.9532163739204407
# precision class 0 = 0.9322034120559692
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.868852436542511
# AUC of ROC = 0.9833084947839046
# AUC of PRC = 0.9771945855296766
# min(+P, Se) = 0.9032258064516129
# f1_score = 0.9298245781896745
# Epoch:27/50 AVG Training Loss:0.145 AVG Val Loss:0.184
# confusion matrix:
# [[110   0]
#  [  8  53]]
# accuracy = 0.9532163739204407
# precision class 0 = 0.9322034120559692
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.868852436542511
# AUC of ROC = 0.9845007451564829
# AUC of PRC = 0.9785755027036054
# min(+P, Se) = 0.9180327868852459
# f1_score = 0.9298245781896745
# Epoch:28/50 AVG Training Loss:0.148 AVG Val Loss:0.181
# confusion matrix:
# [[110   0]
#  [  8  53]]
# accuracy = 0.9532163739204407
# precision class 0 = 0.9322034120559692
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.868852436542511
# AUC of ROC = 0.9846497764530552
# AUC of PRC = 0.9786831226597827
# min(+P, Se) = 0.9180327868852459
# f1_score = 0.9298245781896745
# Epoch:29/50 AVG Training Loss:0.138 AVG Val Loss:0.177
# confusion matrix:
# [[110   0]
#  [  8  53]]
# accuracy = 0.9532163739204407
# precision class 0 = 0.9322034120559692
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.868852436542511
# AUC of ROC = 0.9853949329359166
# AUC of PRC = 0.9796749482662455
# min(+P, Se) = 0.9180327868852459
# f1_score = 0.9298245781896745
# Epoch:30/50 AVG Training Loss:0.133 AVG Val Loss:0.174
# confusion matrix:
# [[110   0]
#  [  8  53]]
# accuracy = 0.9532163739204407
# precision class 0 = 0.9322034120559692
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.868852436542511
# AUC of ROC = 0.9858420268256334
# AUC of PRC = 0.9802106253657914
# min(+P, Se) = 0.9180327868852459
# f1_score = 0.9298245781896745
# Epoch:31/50 AVG Training Loss:0.129 AVG Val Loss:0.171
# confusion matrix:
# [[110   0]
#  [  8  53]]
# accuracy = 0.9532163739204407
# precision class 0 = 0.9322034120559692
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.868852436542511
# AUC of ROC = 0.9856929955290612
# AUC of PRC = 0.9802006614580285
# min(+P, Se) = 0.9180327868852459
# f1_score = 0.9298245781896745
# Epoch:32/50 AVG Training Loss:0.139 AVG Val Loss:0.171
# confusion matrix:
# [[110   0]
#  [  8  53]]
# accuracy = 0.9532163739204407
# precision class 0 = 0.9322034120559692
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.868852436542511
# AUC of ROC = 0.9859910581222056
# AUC of PRC = 0.9804228077408177
# min(+P, Se) = 0.9180327868852459
# f1_score = 0.9298245781896745
# Epoch:33/50 AVG Training Loss:0.132 AVG Val Loss:0.170
# confusion matrix:
# [[110   0]
#  [  8  53]]
# accuracy = 0.9532163739204407
# precision class 0 = 0.9322034120559692
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.868852436542511
# AUC of ROC = 0.9856929955290612
# AUC of PRC = 0.9802006614580285
# min(+P, Se) = 0.9180327868852459
# f1_score = 0.9298245781896745
# Epoch:34/50 AVG Training Loss:0.128 AVG Val Loss:0.171
# confusion matrix:
# [[110   0]
#  [  8  53]]
# accuracy = 0.9532163739204407
# precision class 0 = 0.9322034120559692
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.868852436542511
# AUC of ROC = 0.9855439642324888
# AUC of PRC = 0.9797040473756942
# min(+P, Se) = 0.9047619047619048
# f1_score = 0.9298245781896745
# Epoch:35/50 AVG Training Loss:0.129 AVG Val Loss:0.172
# confusion matrix:
# [[110   0]
#  [  8  53]]
# accuracy = 0.9532163739204407
# precision class 0 = 0.9322034120559692
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.868852436542511
# AUC of ROC = 0.9859910581222058
# AUC of PRC = 0.9801251793002816
# min(+P, Se) = 0.9047619047619048
# f1_score = 0.9298245781896745
# Epoch:36/50 AVG Training Loss:0.125 AVG Val Loss:0.172
# confusion matrix:
# [[110   0]
#  [  7  54]]
# accuracy = 0.9590643048286438
# precision class 0 = 0.94017094373703
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8852459192276001
# AUC of ROC = 0.9870342771982116
# AUC of PRC = 0.9809768345628764
# min(+P, Se) = 0.9047619047619048
# f1_score = 0.9391304446799091
# Epoch:37/50 AVG Training Loss:0.127 AVG Val Loss:0.169
# confusion matrix:
# [[110   0]
#  [  7  54]]
# accuracy = 0.9590643048286438
# precision class 0 = 0.94017094373703
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8852459192276001
# AUC of ROC = 0.987779433681073
# AUC of PRC = 0.9820143179419156
# min(+P, Se) = 0.9180327868852459
# f1_score = 0.9391304446799091
# Epoch:38/50 AVG Training Loss:0.124 AVG Val Loss:0.166
# confusion matrix:
# [[110   0]
#  [  7  54]]
# accuracy = 0.9590643048286438
# precision class 0 = 0.94017094373703
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8852459192276001
# AUC of ROC = 0.9883755588673622
# AUC of PRC = 0.9829072253245318
# min(+P, Se) = 0.9180327868852459
# f1_score = 0.9391304446799091
# Epoch:39/50 AVG Training Loss:0.126 AVG Val Loss:0.165
# confusion matrix:
# [[110   0]
#  [  7  54]]
# accuracy = 0.9590643048286438
# precision class 0 = 0.94017094373703
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8852459192276001
# AUC of ROC = 0.9889716840536513
# AUC of PRC = 0.9834893811094083
# min(+P, Se) = 0.9180327868852459
# f1_score = 0.9391304446799091
# Epoch:40/50 AVG Training Loss:0.127 AVG Val Loss:0.164
# confusion matrix:
# [[110   0]
#  [  7  54]]
# accuracy = 0.9590643048286438
# precision class 0 = 0.94017094373703
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8852459192276001
# AUC of ROC = 0.9901639344262294
# AUC of PRC = 0.9850803447084303
# min(+P, Se) = 0.9344262295081968
# f1_score = 0.9391304446799091
# Epoch:41/50 AVG Training Loss:0.116 AVG Val Loss:0.157
# confusion matrix:
# [[110   0]
#  [  7  54]]
# accuracy = 0.9590643048286438
# precision class 0 = 0.94017094373703
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8852459192276001
# AUC of ROC = 0.9907600596125187
# AUC of PRC = 0.9857771347110373
# min(+P, Se) = 0.9344262295081968
# f1_score = 0.9391304446799091
# Epoch:42/50 AVG Training Loss:0.120 AVG Val Loss:0.153
# confusion matrix:
# [[110   0]
#  [  7  54]]
# accuracy = 0.9590643048286438
# precision class 0 = 0.94017094373703
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8852459192276001
# AUC of ROC = 0.9907600596125187
# AUC of PRC = 0.9857458027922639
# min(+P, Se) = 0.9344262295081968
# f1_score = 0.9391304446799091
# Epoch:43/50 AVG Training Loss:0.111 AVG Val Loss:0.150
# confusion matrix:
# [[110   0]
#  [  7  54]]
# accuracy = 0.9590643048286438
# precision class 0 = 0.94017094373703
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8852459192276001
# AUC of ROC = 0.9913561847988077
# AUC of PRC = 0.9864691768293465
# min(+P, Se) = 0.9344262295081968
# f1_score = 0.9391304446799091
# Epoch:44/50 AVG Training Loss:0.110 AVG Val Loss:0.148
# confusion matrix:
# [[110   0]
#  [  7  54]]
# accuracy = 0.9590643048286438
# precision class 0 = 0.94017094373703
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8852459192276001
# AUC of ROC = 0.9913561847988077
# AUC of PRC = 0.9864691768293465
# min(+P, Se) = 0.9344262295081968
# f1_score = 0.9391304446799091
# Epoch:45/50 AVG Training Loss:0.107 AVG Val Loss:0.148
# confusion matrix:
# [[110   0]
#  [  7  54]]
# accuracy = 0.9590643048286438
# precision class 0 = 0.94017094373703
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8852459192276001
# AUC of ROC = 0.9913561847988077
# AUC of PRC = 0.9864691768293465
# min(+P, Se) = 0.9344262295081968
# f1_score = 0.9391304446799091
# Epoch:46/50 AVG Training Loss:0.110 AVG Val Loss:0.149
# confusion matrix:
# [[110   0]
#  [  7  54]]
# accuracy = 0.9590643048286438
# precision class 0 = 0.94017094373703
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8852459192276001
# AUC of ROC = 0.9913561847988077
# AUC of PRC = 0.9864494303610607
# min(+P, Se) = 0.9344262295081968
# f1_score = 0.9391304446799091
# Epoch:47/50 AVG Training Loss:0.115 AVG Val Loss:0.151
# confusion matrix:
# [[110   0]
#  [  7  54]]
# accuracy = 0.9590643048286438
# precision class 0 = 0.94017094373703
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8852459192276001
# AUC of ROC = 0.9913561847988077
# AUC of PRC = 0.9863559559978341
# min(+P, Se) = 0.9344262295081968
# f1_score = 0.9391304446799091
# Epoch:48/50 AVG Training Loss:0.114 AVG Val Loss:0.148
# confusion matrix:
# [[110   0]
#  [  7  54]]
# accuracy = 0.9590643048286438
# precision class 0 = 0.94017094373703
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8852459192276001
# AUC of ROC = 0.9915052160953801
# AUC of PRC = 0.9865125420311611
# min(+P, Se) = 0.9344262295081968
# f1_score = 0.9391304446799091
# Epoch:49/50 AVG Training Loss:0.104 AVG Val Loss:0.148
# confusion matrix:
# [[110   0]
#  [  7  54]]
# accuracy = 0.9590643048286438
# precision class 0 = 0.94017094373703
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8852459192276001
# AUC of ROC = 0.9915052160953801
# AUC of PRC = 0.9865125420311611
# min(+P, Se) = 0.9344262295081968
# f1_score = 0.9391304446799091
# Epoch:50/50 AVG Training Loss:0.102 AVG Val Loss:0.149
# Best performance on val set 2:         AUROC = 0.9915052160953801
# confusion matrix:
# [[103   4]
#  [  2  71]]
# accuracy = 0.9666666388511658
# precision class 0 = 0.9809523820877075
# precision class 1 = 0.9466666579246521
# recall class 0 = 0.9626168012619019
# recall class 1 = 0.9726027250289917
# AUC of ROC = 0.9955191396748175
# AUC of PRC = 0.9932396254660512
# min(+P, Se) = 0.9726027397260274
# f1_score = 0.9594594776151484
# Performance on test set 2: Accuracy = 0.9666666388511658, AUROC = 0.9955191396748175, AUPRC = 0.9932396254660512
# ====== Test Fold 3 ======
# confusion matrix:
# [[91 19]
#  [ 5 56]]
# accuracy = 0.859649121761322
# precision class 0 = 0.9479166865348816
# precision class 1 = 0.746666669845581
# recall class 0 = 0.8272727131843567
# recall class 1 = 0.9180327653884888
# AUC of ROC = 0.9560357675111772
# AUC of PRC = 0.9544873193709225
# min(+P, Se) = 0.873015873015873
# f1_score = 0.823529405048871
# Epoch:1/50 AVG Training Loss:0.649 AVG Val Loss:0.609
# confusion matrix:
# [[107   3]
#  [  7  54]]
# accuracy = 0.9415204524993896
# precision class 0 = 0.9385964870452881
# precision class 1 = 0.9473684430122375
# recall class 0 = 0.9727272987365723
# recall class 1 = 0.8852459192276001
# AUC of ROC = 0.9655737704918033
# AUC of PRC = 0.9627328831643629
# min(+P, Se) = 0.9016393442622951
# f1_score = 0.9152542271685316
# Epoch:2/50 AVG Training Loss:0.594 AVG Val Loss:0.557
# confusion matrix:
# [[110   0]
#  [  8  53]]
# accuracy = 0.9532163739204407
# precision class 0 = 0.9322034120559692
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.868852436542511
# AUC of ROC = 0.9672131147540983
# AUC of PRC = 0.9635215042683485
# min(+P, Se) = 0.9016393442622951
# f1_score = 0.9298245781896745
# Epoch:3/50 AVG Training Loss:0.539 AVG Val Loss:0.502
# confusion matrix:
# [[110   0]
#  [ 10  51]]
# accuracy = 0.9415204524993896
# precision class 0 = 0.9166666865348816
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8360655903816223
# AUC of ROC = 0.9687034277198212
# AUC of PRC = 0.9643464265974404
# min(+P, Se) = 0.9016393442622951
# f1_score = 0.9107143251339401
# Epoch:4/50 AVG Training Loss:0.482 AVG Val Loss:0.447
# confusion matrix:
# [[110   0]
#  [ 11  50]]
# accuracy = 0.9356725215911865
# precision class 0 = 0.9090909361839294
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8196721076965332
# AUC of ROC = 0.9688524590163934
# AUC of PRC = 0.9639299023847079
# min(+P, Se) = 0.8870967741935484
# f1_score = 0.9009008867362712
# Epoch:5/50 AVG Training Loss:0.424 AVG Val Loss:0.398
# confusion matrix:
# [[110   0]
#  [ 12  49]]
# accuracy = 0.9298245906829834
# precision class 0 = 0.9016393423080444
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8032786846160889
# AUC of ROC = 0.9695976154992548
# AUC of PRC = 0.9646490822254346
# min(+P, Se) = 0.8870967741935484
# f1_score = 0.8909090885052011
# Epoch:6/50 AVG Training Loss:0.384 AVG Val Loss:0.358
# confusion matrix:
# [[110   0]
#  [ 10  51]]
# accuracy = 0.9415204524993896
# precision class 0 = 0.9166666865348816
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8360655903816223
# AUC of ROC = 0.970789865871833
# AUC of PRC = 0.9656209419376756
# min(+P, Se) = 0.9016393442622951
# f1_score = 0.9107143251339401
# Epoch:7/50 AVG Training Loss:0.335 AVG Val Loss:0.328
# confusion matrix:
# [[110   0]
#  [  9  52]]
# accuracy = 0.9473684430122375
# precision class 0 = 0.924369752407074
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8524590134620667
# AUC of ROC = 0.9713859910581222
# AUC of PRC = 0.9657385562757083
# min(+P, Se) = 0.9016393442622951
# f1_score = 0.9203540102056996
# Epoch:8/50 AVG Training Loss:0.308 AVG Val Loss:0.305
# confusion matrix:
# [[110   0]
#  [  8  53]]
# accuracy = 0.9532163739204407
# precision class 0 = 0.9322034120559692
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.868852436542511
# AUC of ROC = 0.9727272727272727
# AUC of PRC = 0.9665955118563787
# min(+P, Se) = 0.9016393442622951
# f1_score = 0.9298245781896745
# Epoch:9/50 AVG Training Loss:0.284 AVG Val Loss:0.285
# confusion matrix:
# [[110   0]
#  [  8  53]]
# accuracy = 0.9532163739204407
# precision class 0 = 0.9322034120559692
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.868852436542511
# AUC of ROC = 0.9737704918032787
# AUC of PRC = 0.9677836966460154
# min(+P, Se) = 0.9016393442622951
# f1_score = 0.9298245781896745
# Epoch:10/50 AVG Training Loss:0.269 AVG Val Loss:0.268
# confusion matrix:
# [[110   0]
#  [  8  53]]
# accuracy = 0.9532163739204407
# precision class 0 = 0.9322034120559692
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.868852436542511
# AUC of ROC = 0.974962742175857
# AUC of PRC = 0.9694219239323374
# min(+P, Se) = 0.9016393442622951
# f1_score = 0.9298245781896745
# Epoch:11/50 AVG Training Loss:0.249 AVG Val Loss:0.252
# confusion matrix:
# [[110   0]
#  [  8  53]]
# accuracy = 0.9532163739204407
# precision class 0 = 0.9322034120559692
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.868852436542511
# AUC of ROC = 0.9764530551415798
# AUC of PRC = 0.9706263360475125
# min(+P, Se) = 0.9016393442622951
# f1_score = 0.9298245781896745
# Epoch:12/50 AVG Training Loss:0.242 AVG Val Loss:0.237
# confusion matrix:
# [[110   0]
#  [  8  53]]
# accuracy = 0.9532163739204407
# precision class 0 = 0.9322034120559692
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.868852436542511
# AUC of ROC = 0.978688524590164
# AUC of PRC = 0.9727357843001322
# min(+P, Se) = 0.9016393442622951
# f1_score = 0.9298245781896745
# Epoch:13/50 AVG Training Loss:0.222 AVG Val Loss:0.225
# confusion matrix:
# [[110   0]
#  [  8  53]]
# accuracy = 0.9532163739204407
# precision class 0 = 0.9322034120559692
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.868852436542511
# AUC of ROC = 0.9794336810730253
# AUC of PRC = 0.973571730813831
# min(+P, Se) = 0.9047619047619048
# f1_score = 0.9298245781896745
# Epoch:14/50 AVG Training Loss:0.204 AVG Val Loss:0.214
# confusion matrix:
# [[110   0]
#  [  8  53]]
# accuracy = 0.9532163739204407
# precision class 0 = 0.9322034120559692
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.868852436542511
# AUC of ROC = 0.9804769001490313
# AUC of PRC = 0.9747580279587236
# min(+P, Se) = 0.9047619047619048
# f1_score = 0.9298245781896745
# Epoch:15/50 AVG Training Loss:0.204 AVG Val Loss:0.205
# confusion matrix:
# [[110   0]
#  [  8  53]]
# accuracy = 0.9532163739204407
# precision class 0 = 0.9322034120559692
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.868852436542511
# AUC of ROC = 0.9812220566318927
# AUC of PRC = 0.9759394831743123
# min(+P, Se) = 0.9180327868852459
# f1_score = 0.9298245781896745
# Epoch:16/50 AVG Training Loss:0.183 AVG Val Loss:0.197
# confusion matrix:
# [[110   0]
#  [  8  53]]
# accuracy = 0.9532163739204407
# precision class 0 = 0.9322034120559692
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.868852436542511
# AUC of ROC = 0.9818181818181818
# AUC of PRC = 0.9764667780575416
# min(+P, Se) = 0.9180327868852459
# f1_score = 0.9298245781896745
# Epoch:17/50 AVG Training Loss:0.183 AVG Val Loss:0.192
# confusion matrix:
# [[110   0]
#  [  8  53]]
# accuracy = 0.9532163739204407
# precision class 0 = 0.9322034120559692
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.868852436542511
# AUC of ROC = 0.9822652757078987
# AUC of PRC = 0.9770610156165098
# min(+P, Se) = 0.9180327868852459
# f1_score = 0.9298245781896745
# Epoch:18/50 AVG Training Loss:0.174 AVG Val Loss:0.187
# confusion matrix:
# [[110   0]
#  [  8  53]]
# accuracy = 0.9532163739204407
# precision class 0 = 0.9322034120559692
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.868852436542511
# AUC of ROC = 0.9833084947839046
# AUC of PRC = 0.9781699319360828
# min(+P, Se) = 0.9180327868852459
# f1_score = 0.9298245781896745
# Epoch:19/50 AVG Training Loss:0.169 AVG Val Loss:0.183
# confusion matrix:
# [[110   0]
#  [  8  53]]
# accuracy = 0.9532163739204407
# precision class 0 = 0.9322034120559692
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.868852436542511
# AUC of ROC = 0.9836065573770492
# AUC of PRC = 0.9785769596099994
# min(+P, Se) = 0.9193548387096774
# f1_score = 0.9298245781896745
# Epoch:20/50 AVG Training Loss:0.168 AVG Val Loss:0.180
# confusion matrix:
# [[110   0]
#  [  8  53]]
# accuracy = 0.9532163739204407
# precision class 0 = 0.9322034120559692
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.868852436542511
# AUC of ROC = 0.9837555886736215
# AUC of PRC = 0.9786873526645441
# min(+P, Se) = 0.9193548387096774
# f1_score = 0.9298245781896745
# Epoch:21/50 AVG Training Loss:0.168 AVG Val Loss:0.179
# confusion matrix:
# [[110   0]
#  [  8  53]]
# accuracy = 0.9532163739204407
# precision class 0 = 0.9322034120559692
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.868852436542511
# AUC of ROC = 0.9842026825633383
# AUC of PRC = 0.9790756675361915
# min(+P, Se) = 0.9193548387096774
# f1_score = 0.9298245781896745
# Epoch:22/50 AVG Training Loss:0.157 AVG Val Loss:0.178
# confusion matrix:
# [[110   0]
#  [  8  53]]
# accuracy = 0.9532163739204407
# precision class 0 = 0.9322034120559692
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.868852436542511
# AUC of ROC = 0.9842026825633382
# AUC of PRC = 0.9789379564879993
# min(+P, Se) = 0.9180327868852459
# f1_score = 0.9298245781896745
# Epoch:23/50 AVG Training Loss:0.145 AVG Val Loss:0.177
# confusion matrix:
# [[110   0]
#  [  8  53]]
# accuracy = 0.9532163739204407
# precision class 0 = 0.9322034120559692
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.868852436542511
# AUC of ROC = 0.9846497764530551
# AUC of PRC = 0.9796244725034968
# min(+P, Se) = 0.9193548387096774
# f1_score = 0.9298245781896745
# Epoch:24/50 AVG Training Loss:0.147 AVG Val Loss:0.175
# confusion matrix:
# [[110   0]
#  [  8  53]]
# accuracy = 0.9532163739204407
# precision class 0 = 0.9322034120559692
# precision class 1 = 1.0
# recall class 0 = 1.0
# ...
# AUC of ROC = 0.9915178571428572
# AUC of PRC = 0.9874442231812097
# min(+P, Se) = 0.921875
# f1_score = 0.896551724137931
# Epoch:7/50 AVG Training Loss:0.375 AVG Val Loss:0.335
# confusion matrix:
# [[105   0]
#  [ 12  52]]
# accuracy = 0.9289940595626831
# precision class 0 = 0.8974359035491943
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.8125
# AUC of ROC = 0.9916666666666666
# AUC of PRC = 0.9874692934313233
# min(+P, Se) = 0.921875
# f1_score = 0.896551724137931
# Epoch:8/50 AVG Training Loss:0.332 AVG Val Loss:0.305
# confusion matrix:
# [[105   0]
#  [  9  55]]
# accuracy = 0.9467455744743347
# precision class 0 = 0.9210526347160339
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.859375
# AUC of ROC = 0.9924107142857144
# AUC of PRC = 0.988501390216639
# min(+P, Se) = 0.9230769230769231
# f1_score = 0.9243697478991597
# Epoch:9/50 AVG Training Loss:0.305 AVG Val Loss:0.279
# confusion matrix:
# [[104   1]
#  [  8  56]]
# accuracy = 0.9467455744743347
# precision class 0 = 0.9285714030265808
# precision class 1 = 0.9824561476707458
# recall class 0 = 0.9904761910438538
# recall class 1 = 0.875
# AUC of ROC = 0.9933035714285715
# AUC of PRC = 0.9897670063875706
# min(+P, Se) = 0.9242424242424242
# f1_score = 0.9256198082568836
# Epoch:10/50 AVG Training Loss:0.284 AVG Val Loss:0.257
# confusion matrix:
# [[104   1]
#  [  7  57]]
# accuracy = 0.9526627063751221
# precision class 0 = 0.9369369149208069
# precision class 1 = 0.982758641242981
# recall class 0 = 0.9904761910438538
# recall class 1 = 0.890625
# AUC of ROC = 0.9938988095238096
# AUC of PRC = 0.9906816964440841
# min(+P, Se) = 0.9375
# f1_score = 0.9344262387988964
# Epoch:11/50 AVG Training Loss:0.273 AVG Val Loss:0.237
# confusion matrix:
# [[104   1]
#  [  7  57]]
# accuracy = 0.9526627063751221
# precision class 0 = 0.9369369149208069
# precision class 1 = 0.982758641242981
# recall class 0 = 0.9904761910438538
# recall class 1 = 0.890625
# AUC of ROC = 0.9946428571428572
# AUC of PRC = 0.9917148325717474
# min(+P, Se) = 0.9393939393939394
# f1_score = 0.9344262387988964
# Epoch:12/50 AVG Training Loss:0.250 AVG Val Loss:0.220
# confusion matrix:
# [[105   0]
#  [  7  57]]
# accuracy = 0.9585798978805542
# precision class 0 = 0.9375
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.890625
# AUC of ROC = 0.9947916666666666
# AUC of PRC = 0.9919729662167893
# min(+P, Se) = 0.9393939393939394
# f1_score = 0.9421487603305785
# Epoch:13/50 AVG Training Loss:0.231 AVG Val Loss:0.203
# confusion matrix:
# [[105   0]
#  [  6  58]]
# accuracy = 0.9644970297813416
# precision class 0 = 0.9459459185600281
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.90625
# AUC of ROC = 0.9952380952380953
# AUC of PRC = 0.9926542999766392
# min(+P, Se) = 0.9393939393939394
# f1_score = 0.9508196721311475
# Epoch:14/50 AVG Training Loss:0.217 AVG Val Loss:0.187
# confusion matrix:
# [[105   0]
#  [  6  58]]
# accuracy = 0.9644970297813416
# precision class 0 = 0.9459459185600281
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.90625
# AUC of ROC = 0.9959821428571428
# AUC of PRC = 0.993732540507396
# min(+P, Se) = 0.9393939393939394
# f1_score = 0.9508196721311475
# Epoch:15/50 AVG Training Loss:0.213 AVG Val Loss:0.176
# confusion matrix:
# [[105   0]
#  [  6  58]]
# accuracy = 0.9644970297813416
# precision class 0 = 0.9459459185600281
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.90625
# AUC of ROC = 0.9970238095238095
# AUC of PRC = 0.9954017030105543
# min(+P, Se) = 0.953125
# f1_score = 0.9508196721311475
# Epoch:16/50 AVG Training Loss:0.204 AVG Val Loss:0.165
# confusion matrix:
# [[105   0]
#  [  5  59]]
# accuracy = 0.9704142212867737
# precision class 0 = 0.9545454382896423
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.921875
# AUC of ROC = 0.9976190476190476
# AUC of PRC = 0.9963575059161169
# min(+P, Se) = 0.953125
# f1_score = 0.959349593495935
# Epoch:17/50 AVG Training Loss:0.192 AVG Val Loss:0.157
# confusion matrix:
# [[105   0]
#  [  5  59]]
# accuracy = 0.9704142212867737
# precision class 0 = 0.9545454382896423
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.921875
# AUC of ROC = 0.9974702380952382
# AUC of PRC = 0.996103424081109
# min(+P, Se) = 0.953125
# f1_score = 0.959349593495935
# Epoch:18/50 AVG Training Loss:0.188 AVG Val Loss:0.150
# confusion matrix:
# [[105   0]
#  [  5  59]]
# accuracy = 0.9704142212867737
# precision class 0 = 0.9545454382896423
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.921875
# AUC of ROC = 0.9973214285714287
# AUC of PRC = 0.9958574739140688
# min(+P, Se) = 0.953125
# f1_score = 0.959349593495935
# Epoch:19/50 AVG Training Loss:0.174 AVG Val Loss:0.146
# confusion matrix:
# [[105   0]
#  [  5  59]]
# accuracy = 0.9704142212867737
# precision class 0 = 0.9545454382896423
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.921875
# AUC of ROC = 0.9974702380952382
# AUC of PRC = 0.996103424081109
# min(+P, Se) = 0.953125
# f1_score = 0.959349593495935
# Epoch:20/50 AVG Training Loss:0.171 AVG Val Loss:0.141
# confusion matrix:
# [[105   0]
#  [  5  59]]
# accuracy = 0.9704142212867737
# precision class 0 = 0.9545454382896423
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.921875
# AUC of ROC = 0.9976190476190476
# AUC of PRC = 0.9963575059161169
# min(+P, Se) = 0.953125
# f1_score = 0.959349593495935
# Epoch:21/50 AVG Training Loss:0.168 AVG Val Loss:0.136
# confusion matrix:
# [[105   0]
#  [  5  59]]
# accuracy = 0.9704142212867737
# precision class 0 = 0.9545454382896423
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.921875
# AUC of ROC = 0.9976190476190476
# AUC of PRC = 0.9963575059161169
# min(+P, Se) = 0.953125
# f1_score = 0.959349593495935
# Epoch:22/50 AVG Training Loss:0.162 AVG Val Loss:0.132
# confusion matrix:
# [[105   0]
#  [  5  59]]
# accuracy = 0.9704142212867737
# precision class 0 = 0.9545454382896423
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.921875
# AUC of ROC = 0.9979166666666668
# AUC of PRC = 0.9968091843342861
# min(+P, Se) = 0.9545454545454546
# f1_score = 0.959349593495935
# Epoch:23/50 AVG Training Loss:0.163 AVG Val Loss:0.128
# confusion matrix:
# [[105   0]
#  [  5  59]]
# accuracy = 0.9704142212867737
# precision class 0 = 0.9545454382896423
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.921875
# AUC of ROC = 0.9979166666666668
# AUC of PRC = 0.9968091843342861
# min(+P, Se) = 0.9545454545454546
# f1_score = 0.959349593495935
# Epoch:24/50 AVG Training Loss:0.158 AVG Val Loss:0.125
# confusion matrix:
# [[105   0]
#  [  4  60]]
# accuracy = 0.976331353187561
# precision class 0 = 0.963302731513977
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.9375
# AUC of ROC = 0.9983630952380953
# AUC of PRC = 0.9974718217827263
# min(+P, Se) = 0.9692307692307692
# f1_score = 0.967741935483871
# Epoch:25/50 AVG Training Loss:0.156 AVG Val Loss:0.121
# confusion matrix:
# [[105   0]
#  [  4  60]]
# accuracy = 0.976331353187561
# precision class 0 = 0.963302731513977
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.9375
# AUC of ROC = 0.9988095238095238
# AUC of PRC = 0.9982024252721189
# min(+P, Se) = 0.984375
# f1_score = 0.967741935483871
# Epoch:26/50 AVG Training Loss:0.152 AVG Val Loss:0.117
# confusion matrix:
# [[105   0]
#  [  4  60]]
# accuracy = 0.976331353187561
# precision class 0 = 0.963302731513977
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.9375
# AUC of ROC = 0.9989583333333334
# AUC of PRC = 0.9984485035211268
# min(+P, Se) = 0.984375
# f1_score = 0.967741935483871
# Epoch:27/50 AVG Training Loss:0.147 AVG Val Loss:0.112
# confusion matrix:
# [[105   0]
#  [  4  60]]
# accuracy = 0.976331353187561
# precision class 0 = 0.963302731513977
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.9375
# AUC of ROC = 0.9991071428571429
# AUC of PRC = 0.9986510093167702
# min(+P, Se) = 0.984375
# f1_score = 0.967741935483871
# Epoch:28/50 AVG Training Loss:0.141 AVG Val Loss:0.108
# confusion matrix:
# [[105   0]
#  [  4  60]]
# accuracy = 0.976331353187561
# precision class 0 = 0.963302731513977
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.9375
# AUC of ROC = 0.9991071428571429
# AUC of PRC = 0.9986510093167702
# min(+P, Se) = 0.984375
# f1_score = 0.967741935483871
# Epoch:29/50 AVG Training Loss:0.139 AVG Val Loss:0.106
# confusion matrix:
# [[105   0]
#  [  4  60]]
# accuracy = 0.976331353187561
# precision class 0 = 0.963302731513977
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.9375
# AUC of ROC = 0.9991071428571429
# AUC of PRC = 0.9986510093167702
# min(+P, Se) = 0.984375
# f1_score = 0.967741935483871
# Epoch:30/50 AVG Training Loss:0.154 AVG Val Loss:0.103
# confusion matrix:
# [[105   0]
#  [  4  60]]
# accuracy = 0.976331353187561
# precision class 0 = 0.963302731513977
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.9375
# AUC of ROC = 0.9991071428571429
# AUC of PRC = 0.9986510093167702
# min(+P, Se) = 0.984375
# f1_score = 0.967741935483871
# Epoch:31/50 AVG Training Loss:0.145 AVG Val Loss:0.102
# confusion matrix:
# [[105   0]
#  [  4  60]]
# accuracy = 0.976331353187561
# precision class 0 = 0.963302731513977
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.9375
# AUC of ROC = 0.9991071428571429
# AUC of PRC = 0.9986510093167702
# min(+P, Se) = 0.984375
# f1_score = 0.967741935483871
# Epoch:32/50 AVG Training Loss:0.140 AVG Val Loss:0.102
# confusion matrix:
# [[105   0]
#  [  4  60]]
# accuracy = 0.976331353187561
# precision class 0 = 0.963302731513977
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.9375
# AUC of ROC = 0.9991071428571429
# AUC of PRC = 0.9986510093167702
# min(+P, Se) = 0.984375
# f1_score = 0.967741935483871
# Epoch:33/50 AVG Training Loss:0.143 AVG Val Loss:0.102
# confusion matrix:
# [[105   0]
#  [  4  60]]
# accuracy = 0.976331353187561
# precision class 0 = 0.963302731513977
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.9375
# AUC of ROC = 0.9995535714285714
# AUC of PRC = 0.9992950729308006
# min(+P, Se) = 0.984375
# f1_score = 0.967741935483871
# Epoch:34/50 AVG Training Loss:0.131 AVG Val Loss:0.098
# confusion matrix:
# [[105   0]
#  [  4  60]]
# accuracy = 0.976331353187561
# precision class 0 = 0.963302731513977
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.9375
# AUC of ROC = 0.9998511904761905
# AUC of PRC = 0.9997577373798077
# min(+P, Se) = 0.9846153846153847
# f1_score = 0.967741935483871
# Epoch:35/50 AVG Training Loss:0.136 AVG Val Loss:0.093
# confusion matrix:
# [[105   0]
#  [  4  60]]
# accuracy = 0.976331353187561
# precision class 0 = 0.963302731513977
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.9375
# AUC of ROC = 0.9998511904761905
# AUC of PRC = 0.9997577373798077
# min(+P, Se) = 0.9846153846153847
# f1_score = 0.967741935483871
# Epoch:36/50 AVG Training Loss:0.133 AVG Val Loss:0.090
# confusion matrix:
# [[105   0]
#  [  4  60]]
# accuracy = 0.976331353187561
# precision class 0 = 0.963302731513977
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.9375
# AUC of ROC = 0.9998511904761905
# AUC of PRC = 0.9997577373798077
# min(+P, Se) = 0.9846153846153847
# f1_score = 0.967741935483871
# Epoch:37/50 AVG Training Loss:0.122 AVG Val Loss:0.089
# confusion matrix:
# [[105   0]
#  [  4  60]]
# accuracy = 0.976331353187561
# precision class 0 = 0.963302731513977
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.9375
# AUC of ROC = 0.9998511904761905
# AUC of PRC = 0.9997577373798077
# min(+P, Se) = 0.9846153846153847
# f1_score = 0.967741935483871
# Epoch:38/50 AVG Training Loss:0.125 AVG Val Loss:0.087
# confusion matrix:
# [[105   0]
#  [  4  60]]
# accuracy = 0.976331353187561
# precision class 0 = 0.963302731513977
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.9375
# AUC of ROC = 0.9998511904761905
# AUC of PRC = 0.9997577373798077
# min(+P, Se) = 0.9846153846153847
# f1_score = 0.967741935483871
# Epoch:39/50 AVG Training Loss:0.119 AVG Val Loss:0.085
# confusion matrix:
# [[105   0]
#  [  4  60]]
# accuracy = 0.976331353187561
# precision class 0 = 0.963302731513977
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.9375
# AUC of ROC = 0.9998511904761905
# AUC of PRC = 0.9997577373798077
# min(+P, Se) = 0.9846153846153847
# f1_score = 0.967741935483871
# Epoch:40/50 AVG Training Loss:0.120 AVG Val Loss:0.083
# confusion matrix:
# [[105   0]
#  [  4  60]]
# accuracy = 0.976331353187561
# precision class 0 = 0.963302731513977
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.9375
# AUC of ROC = 0.9998511904761905
# AUC of PRC = 0.9997577373798077
# min(+P, Se) = 0.9846153846153847
# f1_score = 0.967741935483871
# Epoch:41/50 AVG Training Loss:0.117 AVG Val Loss:0.082
# confusion matrix:
# [[105   0]
#  [  4  60]]
# accuracy = 0.976331353187561
# precision class 0 = 0.963302731513977
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.9375
# AUC of ROC = 0.9998511904761905
# AUC of PRC = 0.9997577373798077
# min(+P, Se) = 0.9846153846153847
# f1_score = 0.967741935483871
# Epoch:42/50 AVG Training Loss:0.121 AVG Val Loss:0.079
# confusion matrix:
# [[105   0]
#  [  4  60]]
# accuracy = 0.976331353187561
# precision class 0 = 0.963302731513977
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.9375
# AUC of ROC = 0.9998511904761905
# AUC of PRC = 0.9997577373798077
# min(+P, Se) = 0.9846153846153847
# f1_score = 0.967741935483871
# Epoch:43/50 AVG Training Loss:0.122 AVG Val Loss:0.079
# confusion matrix:
# [[105   0]
#  [  4  60]]
# accuracy = 0.976331353187561
# precision class 0 = 0.963302731513977
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.9375
# AUC of ROC = 0.9998511904761905
# AUC of PRC = 0.9997577373798077
# min(+P, Se) = 0.9846153846153847
# f1_score = 0.967741935483871
# Epoch:44/50 AVG Training Loss:0.122 AVG Val Loss:0.079
# confusion matrix:
# [[105   0]
#  [  4  60]]
# accuracy = 0.976331353187561
# precision class 0 = 0.963302731513977
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.9375
# AUC of ROC = 0.9998511904761905
# AUC of PRC = 0.9997577373798077
# min(+P, Se) = 0.9846153846153847
# f1_score = 0.967741935483871
# Epoch:45/50 AVG Training Loss:0.115 AVG Val Loss:0.079
# confusion matrix:
# [[105   0]
#  [  4  60]]
# accuracy = 0.976331353187561
# precision class 0 = 0.963302731513977
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.9375
# AUC of ROC = 0.9998511904761905
# AUC of PRC = 0.9997577373798077
# min(+P, Se) = 0.9846153846153847
# f1_score = 0.967741935483871
# Epoch:46/50 AVG Training Loss:0.110 AVG Val Loss:0.077
# confusion matrix:
# [[105   0]
#  [  4  60]]
# accuracy = 0.976331353187561
# precision class 0 = 0.963302731513977
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.9375
# AUC of ROC = 0.9998511904761905
# AUC of PRC = 0.9997577373798077
# min(+P, Se) = 0.9846153846153847
# f1_score = 0.967741935483871
# Epoch:47/50 AVG Training Loss:0.114 AVG Val Loss:0.075
# confusion matrix:
# [[105   0]
#  [  4  60]]
# accuracy = 0.976331353187561
# precision class 0 = 0.963302731513977
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.9375
# AUC of ROC = 0.9998511904761905
# AUC of PRC = 0.9997577373798077
# min(+P, Se) = 0.9846153846153847
# f1_score = 0.967741935483871
# Epoch:48/50 AVG Training Loss:0.114 AVG Val Loss:0.074
# confusion matrix:
# [[105   0]
#  [  4  60]]
# accuracy = 0.976331353187561
# precision class 0 = 0.963302731513977
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.9375
# AUC of ROC = 0.9998511904761905
# AUC of PRC = 0.9997577373798077
# min(+P, Se) = 0.9846153846153847
# f1_score = 0.967741935483871
# Epoch:49/50 AVG Training Loss:0.113 AVG Val Loss:0.074
# confusion matrix:
# [[105   0]
#  [  4  60]]
# accuracy = 0.976331353187561
# precision class 0 = 0.963302731513977
# precision class 1 = 1.0
# recall class 0 = 1.0
# recall class 1 = 0.9375
# AUC of ROC = 1.0
# AUC of PRC = 1.0
# min(+P, Se) = 1.0
# f1_score = 0.967741935483871
# Epoch:50/50 AVG Training Loss:0.101 AVG Val Loss:0.072
# Best performance on val set 10:         AUROC = 1.0
# confusion matrix:
# [[102   9]
#  [  2  53]]
# accuracy = 0.9337349534034729
# precision class 0 = 0.9807692170143127
# precision class 1 = 0.8548387289047241
# recall class 0 = 0.9189189076423645
# recall class 1 = 0.9636363387107849
# AUC of ROC = 0.9914823914823914
# AUC of PRC = 0.9848244704137135
# min(+P, Se) = 0.9090909090909091
# f1_score = 0.905982935460841
# Performance on test set 10: Accuracy = 0.9337349534034729, AUROC = 0.9914823914823914, AUPRC = 0.9848244704137135

# %%
# Calculate average performance on 10-fold test set
print(test_performance)
test_accuracy_list = np.array(test_performance['test_accuracy'])
test_auroc_list = np.array(test_performance['test_auroc'])
test_auprc_list = np.array(test_performance['test_auprc'])
print('accuracy: mean={:.3f}, std={:.3f}'.format(test_accuracy_list.mean(), test_accuracy_list.std()))
print('auroc: mean={:.3f}, std={:.3f}'.format(test_auroc_list.mean(), test_auroc_list.std()))
print('auprc: mean={:.3f}, std={:.3f}'.format(test_auprc_list.mean(), test_auprc_list.std()))

"""
accuracy: mean=0.935, std=0.075
auroc: mean=0.978, std=0.047
auprc: mean=0.965, std=0.078
"""
# Out:
# {'test_loss': [0.13519078493118286, 0.10609977692365646, 0.09619823843240738, 0.2789987027645111, 0.12341393530368805, 0.6481584906578064, 0.11375057697296143, 0.059119813144207, 0.05398879945278168, 0.12142005562782288], 'test_accuracy': [0.9479769, 0.96666664, 0.98285717, 0.9205298, 0.9322034, 0.72, 0.96732026, 0.98351645, 0.99418604, 0.93373495], 'test_auroc': [0.9883885584820165, 0.9955191396748175, 0.9991079393398751, 0.9772727272727273, 0.9944193462662769, 0.8370937416062314, 0.9982443820224719, 0.9998666133119914, 0.9998592936541438, 0.9914823914823914], 'test_auprc': [0.9846828218253756, 0.9932396254660512, 0.9982630405534096, 0.9688678511899442, 0.9916400808836439, 0.7323535854185843, 0.9976396398867099, 0.9997500157470396, 0.9997914603774714, 0.9848244704137135]}
# accuracy: mean=0.935, std=0.075
# auroc: mean=0.978, std=0.047
# auprc: mean=0.965, std=0.078
# '\naccuracy: mean=0.956, std=0.025\nauroc: mean=0.986, std=0.015\nauprc: mean=0.984, std=0.018\n'
